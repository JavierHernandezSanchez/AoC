# %% [markdown]
# # AoC 10
#
# The CPU has a single register, X, which starts with the value 1.
#
# It supports only two instructions:
#
# * addx V takes two cycles to complete. After two cycles, the X register is increased by the value V. (V can be negative.)
# * noop takes one cycle to complete. It has no other effect.
#
# Consider the following small program:
#
# * noop
# * addx 3
# * addx -5
#
# Execution of this program proceeds as follows:
#
# At the start of the first cycle, the noop instruction begins execution. \
# During the first cycle, X is 1. \
# After the first cycle, the noop instruction finishes execution, doing nothing.
#
# At the start of the second cycle, the addx 3 instruction begins execution. \
# During the second cycle, X is still 1.\
# During the third cycle, X is still 1. \
# After the third cycle, the addx 3 instruction finishes execution, setting X to 4.
#
# At the start of the fourth cycle, the addx -5 instruction begins execution. \
# During the fourth cycle, X is still 4.\
# During the fifth cycle, X is still 4. \
# After the fifth cycle, the addx -5 instruction finishes execution, setting X to -1.
#
# The signal strength (the cycle number multiplied by the value of the X register)
# during the 20th cycle and every 40 cycles after that (that is, during the 20th, 60th, 100th, 140th, 180th, and 220th cycles)
#
# in the test 2 the interesting signal strengths can be determined as follows:
#
# - During the 20th cycle, register X has the value 21, so the signal strength is 20 * 21 = 420. (The 20th cycle occurs in the middle of the second addx -1, so the value of register X is the starting value, 1, plus all of the other addx values up to that point: 1 + 15 - 11 + 6 - 3 + 5 - 1 - 8 + 13 + 4 = 21.)\
# - During the 60th cycle, register X has the value 19, so the signal strength is 60 * 19 = 1140.\
# - During the 100th cycle, register X has the value 18, so the signal strength is 100 * 18 = 1800.\
# - During the 140th cycle, register X has the value 21, so the signal strength is 140 * 21 = 2940.\
# - During the 180th cycle, register X has the value 16, so the signal strength is 180 * 16 = 2880.\
# - During the 220th cycle, register X has the value 18, so the signal strength is 220 * 18 = 3960.\
#
# The sum of these signal strengths is 13140.
#
# Find the signal strength during the 20th, 60th, 100th, 140th, 180th, and 220th cycles. What is the sum of these six signal strengths?

# %%
def get_input(filename):
    instructions = []
    with open(filename) as file:
        for line in file:            
            instructions.append(line.strip())
    return instructions

# %%
def acummulated_strength(instructions, verbose=False):
    val = 1
    cycle = 0
    acum = 0
    for inst in instructions:
        if inst.startswith('noop'):
            cycle += 1
            if cycle == 20 or (cycle - 20) % 40 == 0:
                print(f'({inst}) cycle: {cycle } val: {val} strength: {cycle * val}')
                acum += cycle * val
            if verbose:
                print(f'cycle: {cycle} = {val}')
        else:
            istr, xstr = inst.split()
            x = int(xstr)
            if cycle + 1 == 20 or (cycle + 1 - 20) % 40 == 0:
                print(f'({inst}) cycle: {cycle + 1} val: {val} strength: {(cycle + 1) * val}')
                acum += (cycle + 1) * val
                if verbose:
                    print(f'cycle: {cycle + 1} = {val}')
            elif cycle + 2 == 20 or (cycle + 2 - 20) % 40 == 0:
                print(f'({inst}) cycle: {cycle + 2} val: {val} strength: {(cycle + 2) * val}')
                acum += (cycle + 2) * val
                if verbose:
                    print(f'cycle: {cycle + 2} = {val}')
            val += x
            cycle += 2
            if verbose:
                print(f'cycle: {cycle} = {val}')
    return acum

# %%
instructions = get_input('test1.txt')
strength = acummulated_strength(instructions, verbose=True)
strength
# Out:
# cycle: 1 = 1
# cycle: 3 = 4
# cycle: 5 = -1
# 0

# %%
instructions = get_input('test2.txt')
strength = acummulated_strength(instructions, verbose=False)
strength
# Out:
# (addx -1) cycle: 20 val: 21 strength: 420
# (addx -3) cycle: 60 val: 19 strength: 1140
# (noop) cycle: 100 val: 18 strength: 1800
# (addx 1) cycle: 140 val: 21 strength: 2940
# (addx -9) cycle: 180 val: 16 strength: 2880
# (addx 1) cycle: 220 val: 18 strength: 3960
# 13140

# %%
instructions = get_input('input.txt')
strength = acummulated_strength(instructions, verbose=False)
strength
# Out:
# (addx 17) cycle: 20 val: 21 strength: 420
# (addx 2) cycle: 60 val: 17 strength: 1020
# (addx 17) cycle: 100 val: 4 strength: 400
# (addx 3) cycle: 140 val: 21 strength: 2940
# (addx -10) cycle: 180 val: 21 strength: 3780
# (addx 11) cycle: 220 val: 21 strength: 4620
# 13180

# %% [markdown]
# ### Part 2
#
# It seems like the X register controls the horizontal position of a sprite. Specifically, the sprite is 3 pixels wide, and the X register sets the horizontal position of the middle of that sprite. (In this system, there is no such thing as "vertical position": if the sprite's horizontal position puts its pixels where the CRT is currently drawing, then those pixels will be drawn.)
#
# You count the pixels on the CRT: 40 wide and 6 high. This CRT screen draws the top row of pixels left-to-right, then the row below that, and so on. The left-most pixel in each row is in position 0, and the right-most pixel in each row is in position 39.
#
# Like the CPU, the CRT is tied closely to the clock circuit: the CRT draws a single pixel during each cycle. Representing each pixel of the screen as a #, here are the cycles during which the first and last pixel in each row are drawn:
#
# Cycle   1 -> ######################################## <- Cycle  40 <br>
# Cycle  41 -> ######################################## <- Cycle  80 <br>
# Cycle  81 -> ######################################## <- Cycle 120 <br>
# Cycle 121 -> ######################################## <- Cycle 160 <br>
# Cycle 161 -> ######################################## <- Cycle 200 <br>
# Cycle 201 -> ######################################## <- Cycle 240 <br>
#
# So, by carefully timing the CPU instructions and the CRT drawing operations, you should be able to determine whether the sprite is visible the instant each pixel is drawn. If the sprite is positioned such that one of its three pixels is the pixel currently being drawn, the screen produces a lit pixel (#); otherwise, the screen leaves the pixel dark (.).
#
# The first few pixels from the larger example above are drawn as follows:
#
# Sprite position: ###..................................... <br>
#
# Start cycle   1: begin executing addx 15 <br>
# During cycle  1: CRT draws pixel in position 0 <br>
# Current CRT row: # <br>
#
# During cycle  2: CRT draws pixel in position 1 <br>
# Current CRT row: ## <br>
# End of cycle  2: finish executing addx 15 (Register X is now 16) <br>
# Sprite position: ...............###...................... <br>
#
# Start cycle   3: begin executing addx -11 <br>
# During cycle  3: CRT draws pixel in position 2 <br>
# Current CRT row: ##. <br>
#
# During cycle  4: CRT draws pixel in position 3 <br>
# Current CRT row: ##.. <br>
# End of cycle  4: finish executing addx -11 (Register X is now 5) <br>
# Sprite position: ....###................................. <br>
#
# Start cycle   5: begin executing addx 6 <br>
# During cycle  5: CRT draws pixel in position 4 <br>
# Current CRT row: ##..# <br>
#
# During cycle  6: CRT draws pixel in position 5 <br>
# Current CRT row: ##..## <br>
# End of cycle  6: finish executing addx 6 (Register X is now 11) <br>
# Sprite position: ..........###........................... <br>
#
# Start cycle   7: begin executing addx -3 <br>
# During cycle  7: CRT draws pixel in position 6 <br>
# Current CRT row: ##..##. <br>
#
# During cycle  8: CRT draws pixel in position 7 <br>
# Current CRT row: ##..##.. <br>
# End of cycle  8: finish executing addx -3 (Register X is now 8) <br>
# Sprite position: .......###.............................. <br>
#
# Start cycle   9: begin executing addx 5 <br>
# During cycle  9: CRT draws pixel in position 8 <br>
# Current CRT row: ##..##..# <br>
#
# During cycle 10: CRT draws pixel in position 9 <br>
# Current CRT row: ##..##..## <br>
# End of cycle 10: finish executing addx 5 (Register X is now 13) <br>
# Sprite position: ............###......................... <br>
#
# Start cycle  11: begin executing addx -1 <br>
# During cycle 11: CRT draws pixel in position 10 <br>
# Current CRT row: ##..##..##. <br>
#
# During cycle 12: CRT draws pixel in position 11 <br>
# Current CRT row: ##..##..##.. <br>
# End of cycle 12: finish executing addx -1 (Register X is now 12) <br>
# Sprite position: ...........###.......................... <br>
#
# Start cycle  13: begin executing addx -8 <br>
# During cycle 13: CRT draws pixel in position 12 <br>
# Current CRT row: ##..##..##..# <br>
#
# During cycle 14: CRT draws pixel in position 13 <br>
# Current CRT row: ##..##..##..## <br>
# End of cycle 14: finish executing addx -8 (Register X is now 4) <br>
# Sprite position: ...###.................................. <br>
#
# Start cycle  15: begin executing addx 13 <br>
# During cycle 15: CRT draws pixel in position 14 <br>
# Current CRT row: ##..##..##..##. <br>
#
# During cycle 16: CRT draws pixel in position 15 <br>
# Current CRT row: ##..##..##..##.. <br>
# End of cycle 16: finish executing addx 13 (Register X is now 17) <br>
# Sprite position: ................###..................... <br>
#
# Start cycle  17: begin executing addx 4 <br>
# During cycle 17: CRT draws pixel in position 16 <br>
# Current CRT row: ##..##..##..##..# <br>
#
# During cycle 18: CRT draws pixel in position 17 <br>
# Current CRT row: ##..##..##..##..## <br>
# End of cycle 18: finish executing addx 4 (Register X is now 21) <br>
# Sprite position: ....................###................. <br>
#
# Start cycle  19: begin executing noop <br>
# During cycle 19: CRT draws pixel in position 18 <br>
# Current CRT row: ##..##..##..##..##. <br>
# End of cycle 19: finish executing noop <br>
#
# Start cycle  20: begin executing addx -1 <br>
# During cycle 20: CRT draws pixel in position 19 <br>
# Current CRT row: ##..##..##..##..##.. <br>
#
# During cycle 21: CRT draws pixel in position 20 <br>
# Current CRT row: ##..##..##..##..##..# <br>
# End of cycle 21: finish executing addx -1 (Register X is now 20) <br>
# Sprite position: ...................###.................. <br>
#
# Allowing the program to run to completion causes the CRT to produce the following image:
#
# ##..##..##..##..##..##..##..##..##..##.. <br>
# ###...###...###...###...###...###...###. <br>
# ####....####....####....####....####.... <br>
# #####.....#####.....#####.....#####..... <br>
# ######......######......######......#### <br>
# #######.......#######.......#######..... <br>
#
# Render the image given by your program. What eight capital letters appear on your CRT?

# %%
def print_sprite_pos(crt_col):
    print('Sprite position: ', end='')
    for i in range(40):
        if i in [crt_col-1, crt_col, crt_col+1]:
            print('#', end='')
        else:
            print('.', end='')
    print('')
    
def run_cycle(x, cycle, inst, crt_col, crt_text, full_text, updx):
    if not inst.startswith('noop'):
        istr, xstr = inst.split()
    
    print_sprite_pos(x)
    print(f'Start cycle\t{cycle}: begin executing {inst}')
    print(f'During cycle\t{cycle}: CRT draws pixel in position {crt_col}')            
    if crt_col in [x-1, x, x+1]:
        crt_text += '#'
    else:
        crt_text += '.'            

    print(f'Current CRT row: {crt_text}')
    
    if updx:
        x += int(xstr)
        
    print(f'End of cycle\t{cycle}: finish executing {inst} (Register X is now {x})\n')
    cycle += 1
    crt_col += 1
    
    if crt_col % 40 == 0:
        full_text.append(crt_text)
        crt_col = 0
        crt_text = ''
        
    return x, crt_col, crt_text, cycle
        
def draw_screen(instructions, verbose=False):
    x = 1
    crt_col = 0
    cycle = 1
    crt_text = ''    
    full_text = []
    
    for inst in instructions:
        if inst.startswith('noop'):
            x, crt_col, crt_text, cycle = run_cycle(x, cycle, inst, crt_col, crt_text, full_text, False)
        else:
            #cycle 1
            x, crt_col, crt_text, cycle = run_cycle(x, cycle, inst, crt_col, crt_text, full_text, False)
            
            #cycle 2
            x, crt_col, crt_text, cycle = run_cycle(x, cycle, inst, crt_col, crt_text, full_text, True)
    
    return full_text

# %%
instructions = get_input('test2.txt')
w = draw_screen(instructions, verbose=True)
print('\n'.join(w))
# Out:
# Sprite position: ###.....................................
# Start cycle	1: begin executing addx 15
# During cycle	1: CRT draws pixel in position 0
# Current CRT row: #
# End of cycle	1: finish executing addx 15 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	2: begin executing addx 15
# During cycle	2: CRT draws pixel in position 1
# Current CRT row: ##
# End of cycle	2: finish executing addx 15 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	3: begin executing addx -11
# During cycle	3: CRT draws pixel in position 2
# Current CRT row: ##.
# End of cycle	3: finish executing addx -11 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	4: begin executing addx -11
# During cycle	4: CRT draws pixel in position 3
# Current CRT row: ##..
# End of cycle	4: finish executing addx -11 (Register X is now 5)
#
# Sprite position: ....###.................................
# Start cycle	5: begin executing addx 6
# During cycle	5: CRT draws pixel in position 4
# Current CRT row: ##..#
# End of cycle	5: finish executing addx 6 (Register X is now 5)
#
# Sprite position: ....###.................................
# Start cycle	6: begin executing addx 6
# During cycle	6: CRT draws pixel in position 5
# Current CRT row: ##..##
# End of cycle	6: finish executing addx 6 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	7: begin executing addx -3
# During cycle	7: CRT draws pixel in position 6
# Current CRT row: ##..##.
# End of cycle	7: finish executing addx -3 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	8: begin executing addx -3
# During cycle	8: CRT draws pixel in position 7
# Current CRT row: ##..##..
# End of cycle	8: finish executing addx -3 (Register X is now 8)
#
# Sprite position: .......###..............................
# Start cycle	9: begin executing addx 5
# During cycle	9: CRT draws pixel in position 8
# Current CRT row: ##..##..#
# End of cycle	9: finish executing addx 5 (Register X is now 8)
#
# Sprite position: .......###..............................
# Start cycle	10: begin executing addx 5
# During cycle	10: CRT draws pixel in position 9
# Current CRT row: ##..##..##
# End of cycle	10: finish executing addx 5 (Register X is now 13)
#
# Sprite position: ............###.........................
# Start cycle	11: begin executing addx -1
# During cycle	11: CRT draws pixel in position 10
# Current CRT row: ##..##..##.
# End of cycle	11: finish executing addx -1 (Register X is now 13)
#
# Sprite position: ............###.........................
# Start cycle	12: begin executing addx -1
# During cycle	12: CRT draws pixel in position 11
# Current CRT row: ##..##..##..
# End of cycle	12: finish executing addx -1 (Register X is now 12)
#
# Sprite position: ...........###..........................
# Start cycle	13: begin executing addx -8
# During cycle	13: CRT draws pixel in position 12
# Current CRT row: ##..##..##..#
# End of cycle	13: finish executing addx -8 (Register X is now 12)
#
# Sprite position: ...........###..........................
# Start cycle	14: begin executing addx -8
# During cycle	14: CRT draws pixel in position 13
# Current CRT row: ##..##..##..##
# End of cycle	14: finish executing addx -8 (Register X is now 4)
#
# Sprite position: ...###..................................
# Start cycle	15: begin executing addx 13
# During cycle	15: CRT draws pixel in position 14
# Current CRT row: ##..##..##..##.
# End of cycle	15: finish executing addx 13 (Register X is now 4)
#
# Sprite position: ...###..................................
# Start cycle	16: begin executing addx 13
# During cycle	16: CRT draws pixel in position 15
# Current CRT row: ##..##..##..##..
# End of cycle	16: finish executing addx 13 (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	17: begin executing addx 4
# During cycle	17: CRT draws pixel in position 16
# Current CRT row: ##..##..##..##..#
# End of cycle	17: finish executing addx 4 (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	18: begin executing addx 4
# During cycle	18: CRT draws pixel in position 17
# Current CRT row: ##..##..##..##..##
# End of cycle	18: finish executing addx 4 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	19: begin executing noop
# During cycle	19: CRT draws pixel in position 18
# Current CRT row: ##..##..##..##..##.
# End of cycle	19: finish executing noop (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	20: begin executing addx -1
# During cycle	20: CRT draws pixel in position 19
# Current CRT row: ##..##..##..##..##..
# End of cycle	20: finish executing addx -1 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	21: begin executing addx -1
# During cycle	21: CRT draws pixel in position 20
# Current CRT row: ##..##..##..##..##..#
# End of cycle	21: finish executing addx -1 (Register X is now 20)
#
# Sprite position: ...................###..................
# Start cycle	22: begin executing addx 5
# During cycle	22: CRT draws pixel in position 21
# Current CRT row: ##..##..##..##..##..##
# End of cycle	22: finish executing addx 5 (Register X is now 20)
#
# Sprite position: ...................###..................
# Start cycle	23: begin executing addx 5
# During cycle	23: CRT draws pixel in position 22
# Current CRT row: ##..##..##..##..##..##.
# End of cycle	23: finish executing addx 5 (Register X is now 25)
#
# Sprite position: ........................###.............
# Start cycle	24: begin executing addx -1
# During cycle	24: CRT draws pixel in position 23
# Current CRT row: ##..##..##..##..##..##..
# End of cycle	24: finish executing addx -1 (Register X is now 25)
#
# Sprite position: ........................###.............
# Start cycle	25: begin executing addx -1
# During cycle	25: CRT draws pixel in position 24
# Current CRT row: ##..##..##..##..##..##..#
# End of cycle	25: finish executing addx -1 (Register X is now 24)
#
# Sprite position: .......................###..............
# Start cycle	26: begin executing addx 5
# During cycle	26: CRT draws pixel in position 25
# Current CRT row: ##..##..##..##..##..##..##
# End of cycle	26: finish executing addx 5 (Register X is now 24)
#
# Sprite position: .......................###..............
# Start cycle	27: begin executing addx 5
# During cycle	27: CRT draws pixel in position 26
# Current CRT row: ##..##..##..##..##..##..##.
# End of cycle	27: finish executing addx 5 (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	28: begin executing addx -1
# During cycle	28: CRT draws pixel in position 27
# Current CRT row: ##..##..##..##..##..##..##..
# End of cycle	28: finish executing addx -1 (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	29: begin executing addx -1
# During cycle	29: CRT draws pixel in position 28
# Current CRT row: ##..##..##..##..##..##..##..#
# End of cycle	29: finish executing addx -1 (Register X is now 28)
#
# Sprite position: ...........................###..........
# Start cycle	30: begin executing addx 5
# During cycle	30: CRT draws pixel in position 29
# Current CRT row: ##..##..##..##..##..##..##..##
# End of cycle	30: finish executing addx 5 (Register X is now 28)
#
# Sprite position: ...........................###..........
# Start cycle	31: begin executing addx 5
# During cycle	31: CRT draws pixel in position 30
# Current CRT row: ##..##..##..##..##..##..##..##.
# End of cycle	31: finish executing addx 5 (Register X is now 33)
#
# Sprite position: ................................###.....
# Start cycle	32: begin executing addx -1
# During cycle	32: CRT draws pixel in position 31
# Current CRT row: ##..##..##..##..##..##..##..##..
# End of cycle	32: finish executing addx -1 (Register X is now 33)
#
# Sprite position: ................................###.....
# Start cycle	33: begin executing addx -1
# During cycle	33: CRT draws pixel in position 32
# Current CRT row: ##..##..##..##..##..##..##..##..#
# End of cycle	33: finish executing addx -1 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	34: begin executing addx 5
# During cycle	34: CRT draws pixel in position 33
# Current CRT row: ##..##..##..##..##..##..##..##..##
# End of cycle	34: finish executing addx 5 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	35: begin executing addx 5
# During cycle	35: CRT draws pixel in position 34
# Current CRT row: ##..##..##..##..##..##..##..##..##.
# End of cycle	35: finish executing addx 5 (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	36: begin executing addx -1
# During cycle	36: CRT draws pixel in position 35
# Current CRT row: ##..##..##..##..##..##..##..##..##..
# End of cycle	36: finish executing addx -1 (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	37: begin executing addx -1
# During cycle	37: CRT draws pixel in position 36
# Current CRT row: ##..##..##..##..##..##..##..##..##..#
# End of cycle	37: finish executing addx -1 (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	38: begin executing addx -35
# During cycle	38: CRT draws pixel in position 37
# Current CRT row: ##..##..##..##..##..##..##..##..##..##
# End of cycle	38: finish executing addx -35 (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	39: begin executing addx -35
# During cycle	39: CRT draws pixel in position 38
# Current CRT row: ##..##..##..##..##..##..##..##..##..##.
# End of cycle	39: finish executing addx -35 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	40: begin executing addx 1
# During cycle	40: CRT draws pixel in position 39
# Current CRT row: ##..##..##..##..##..##..##..##..##..##..
# End of cycle	40: finish executing addx 1 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	41: begin executing addx 1
# During cycle	41: CRT draws pixel in position 0
# Current CRT row: #
# End of cycle	41: finish executing addx 1 (Register X is now 2)
#
# Sprite position: .###....................................
# Start cycle	42: begin executing addx 24
# During cycle	42: CRT draws pixel in position 1
# Current CRT row: ##
# End of cycle	42: finish executing addx 24 (Register X is now 2)
#
# Sprite position: .###....................................
# Start cycle	43: begin executing addx 24
# During cycle	43: CRT draws pixel in position 2
# Current CRT row: ###
# End of cycle	43: finish executing addx 24 (Register X is now 26)
#
# Sprite position: .........................###............
# Start cycle	44: begin executing addx -19
# During cycle	44: CRT draws pixel in position 3
# Current CRT row: ###.
# End of cycle	44: finish executing addx -19 (Register X is now 26)
#
# Sprite position: .........................###............
# Start cycle	45: begin executing addx -19
# During cycle	45: CRT draws pixel in position 4
# Current CRT row: ###..
# End of cycle	45: finish executing addx -19 (Register X is now 7)
#
# Sprite position: ......###...............................
# Start cycle	46: begin executing addx 1
# During cycle	46: CRT draws pixel in position 5
# Current CRT row: ###...
# End of cycle	46: finish executing addx 1 (Register X is now 7)
#
# Sprite position: ......###...............................
# Start cycle	47: begin executing addx 1
# During cycle	47: CRT draws pixel in position 6
# Current CRT row: ###...#
# End of cycle	47: finish executing addx 1 (Register X is now 8)
#
# Sprite position: .......###..............................
# Start cycle	48: begin executing addx 16
# During cycle	48: CRT draws pixel in position 7
# Current CRT row: ###...##
# End of cycle	48: finish executing addx 16 (Register X is now 8)
#
# Sprite position: .......###..............................
# Start cycle	49: begin executing addx 16
# During cycle	49: CRT draws pixel in position 8
# Current CRT row: ###...###
# End of cycle	49: finish executing addx 16 (Register X is now 24)
#
# Sprite position: .......................###..............
# Start cycle	50: begin executing addx -11
# During cycle	50: CRT draws pixel in position 9
# Current CRT row: ###...###.
# End of cycle	50: finish executing addx -11 (Register X is now 24)
#
# Sprite position: .......................###..............
# Start cycle	51: begin executing addx -11
# During cycle	51: CRT draws pixel in position 10
# Current CRT row: ###...###..
# End of cycle	51: finish executing addx -11 (Register X is now 13)
#
# Sprite position: ............###.........................
# Start cycle	52: begin executing noop
# During cycle	52: CRT draws pixel in position 11
# Current CRT row: ###...###...
# End of cycle	52: finish executing noop (Register X is now 13)
#
# Sprite position: ............###.........................
# Start cycle	53: begin executing noop
# During cycle	53: CRT draws pixel in position 12
# Current CRT row: ###...###...#
# End of cycle	53: finish executing noop (Register X is now 13)
#
# Sprite position: ............###.........................
# Start cycle	54: begin executing addx 21
# During cycle	54: CRT draws pixel in position 13
# Current CRT row: ###...###...##
# End of cycle	54: finish executing addx 21 (Register X is now 13)
#
# Sprite position: ............###.........................
# Start cycle	55: begin executing addx 21
# During cycle	55: CRT draws pixel in position 14
# Current CRT row: ###...###...###
# End of cycle	55: finish executing addx 21 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	56: begin executing addx -15
# During cycle	56: CRT draws pixel in position 15
# Current CRT row: ###...###...###.
# End of cycle	56: finish executing addx -15 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	57: begin executing addx -15
# During cycle	57: CRT draws pixel in position 16
# Current CRT row: ###...###...###..
# End of cycle	57: finish executing addx -15 (Register X is now 19)
#
# Sprite position: ..................###...................
# Start cycle	58: begin executing noop
# During cycle	58: CRT draws pixel in position 17
# Current CRT row: ###...###...###...
# End of cycle	58: finish executing noop (Register X is now 19)
#
# Sprite position: ..................###...................
# Start cycle	59: begin executing noop
# During cycle	59: CRT draws pixel in position 18
# Current CRT row: ###...###...###...#
# End of cycle	59: finish executing noop (Register X is now 19)
#
# Sprite position: ..................###...................
# Start cycle	60: begin executing addx -3
# During cycle	60: CRT draws pixel in position 19
# Current CRT row: ###...###...###...##
# End of cycle	60: finish executing addx -3 (Register X is now 19)
#
# Sprite position: ..................###...................
# Start cycle	61: begin executing addx -3
# During cycle	61: CRT draws pixel in position 20
# Current CRT row: ###...###...###...###
# End of cycle	61: finish executing addx -3 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	62: begin executing addx 9
# During cycle	62: CRT draws pixel in position 21
# Current CRT row: ###...###...###...###.
# End of cycle	62: finish executing addx 9 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	63: begin executing addx 9
# During cycle	63: CRT draws pixel in position 22
# Current CRT row: ###...###...###...###..
# End of cycle	63: finish executing addx 9 (Register X is now 25)
#
# Sprite position: ........................###.............
# Start cycle	64: begin executing addx 1
# During cycle	64: CRT draws pixel in position 23
# Current CRT row: ###...###...###...###...
# End of cycle	64: finish executing addx 1 (Register X is now 25)
#
# Sprite position: ........................###.............
# Start cycle	65: begin executing addx 1
# During cycle	65: CRT draws pixel in position 24
# Current CRT row: ###...###...###...###...#
# End of cycle	65: finish executing addx 1 (Register X is now 26)
#
# Sprite position: .........................###............
# Start cycle	66: begin executing addx -3
# During cycle	66: CRT draws pixel in position 25
# Current CRT row: ###...###...###...###...##
# End of cycle	66: finish executing addx -3 (Register X is now 26)
#
# Sprite position: .........................###............
# Start cycle	67: begin executing addx -3
# During cycle	67: CRT draws pixel in position 26
# Current CRT row: ###...###...###...###...###
# End of cycle	67: finish executing addx -3 (Register X is now 23)
#
# Sprite position: ......................###...............
# Start cycle	68: begin executing addx 8
# During cycle	68: CRT draws pixel in position 27
# Current CRT row: ###...###...###...###...###.
# End of cycle	68: finish executing addx 8 (Register X is now 23)
#
# Sprite position: ......................###...............
# Start cycle	69: begin executing addx 8
# During cycle	69: CRT draws pixel in position 28
# Current CRT row: ###...###...###...###...###..
# End of cycle	69: finish executing addx 8 (Register X is now 31)
#
# Sprite position: ..............................###.......
# Start cycle	70: begin executing addx 1
# During cycle	70: CRT draws pixel in position 29
# Current CRT row: ###...###...###...###...###...
# End of cycle	70: finish executing addx 1 (Register X is now 31)
#
# Sprite position: ..............................###.......
# Start cycle	71: begin executing addx 1
# During cycle	71: CRT draws pixel in position 30
# Current CRT row: ###...###...###...###...###...#
# End of cycle	71: finish executing addx 1 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	72: begin executing addx 5
# During cycle	72: CRT draws pixel in position 31
# Current CRT row: ###...###...###...###...###...##
# End of cycle	72: finish executing addx 5 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	73: begin executing addx 5
# During cycle	73: CRT draws pixel in position 32
# Current CRT row: ###...###...###...###...###...###
# End of cycle	73: finish executing addx 5 (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	74: begin executing noop
# During cycle	74: CRT draws pixel in position 33
# Current CRT row: ###...###...###...###...###...###.
# End of cycle	74: finish executing noop (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	75: begin executing noop
# During cycle	75: CRT draws pixel in position 34
# Current CRT row: ###...###...###...###...###...###..
# End of cycle	75: finish executing noop (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	76: begin executing noop
# During cycle	76: CRT draws pixel in position 35
# Current CRT row: ###...###...###...###...###...###...
# End of cycle	76: finish executing noop (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	77: begin executing noop
# During cycle	77: CRT draws pixel in position 36
# Current CRT row: ###...###...###...###...###...###...#
# End of cycle	77: finish executing noop (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	78: begin executing noop
# During cycle	78: CRT draws pixel in position 37
# Current CRT row: ###...###...###...###...###...###...##
# End of cycle	78: finish executing noop (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	79: begin executing addx -36
# During cycle	79: CRT draws pixel in position 38
# Current CRT row: ###...###...###...###...###...###...###
# End of cycle	79: finish executing addx -36 (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	80: begin executing addx -36
# During cycle	80: CRT draws pixel in position 39
# Current CRT row: ###...###...###...###...###...###...###.
# End of cycle	80: finish executing addx -36 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	81: begin executing noop
# During cycle	81: CRT draws pixel in position 0
# Current CRT row: #
# End of cycle	81: finish executing noop (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	82: begin executing addx 1
# During cycle	82: CRT draws pixel in position 1
# Current CRT row: ##
# End of cycle	82: finish executing addx 1 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	83: begin executing addx 1
# During cycle	83: CRT draws pixel in position 2
# Current CRT row: ###
# End of cycle	83: finish executing addx 1 (Register X is now 2)
#
# Sprite position: .###....................................
# Start cycle	84: begin executing addx 7
# During cycle	84: CRT draws pixel in position 3
# Current CRT row: ####
# End of cycle	84: finish executing addx 7 (Register X is now 2)
#
# Sprite position: .###....................................
# Start cycle	85: begin executing addx 7
# During cycle	85: CRT draws pixel in position 4
# Current CRT row: ####.
# End of cycle	85: finish executing addx 7 (Register X is now 9)
# Sprite position: ........###.............................
# Start cycle	86: begin executing noop
# During cycle	86: CRT draws pixel in position 5
# Current CRT row: ####..
# End of cycle	86: finish executing noop (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	87: begin executing noop
# During cycle	87: CRT draws pixel in position 6
# Current CRT row: ####...
# End of cycle	87: finish executing noop (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	88: begin executing noop
# During cycle	88: CRT draws pixel in position 7
# Current CRT row: ####....
# End of cycle	88: finish executing noop (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	89: begin executing addx 2
# During cycle	89: CRT draws pixel in position 8
# Current CRT row: ####....#
# End of cycle	89: finish executing addx 2 (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	90: begin executing addx 2
# During cycle	90: CRT draws pixel in position 9
# Current CRT row: ####....##
# End of cycle	90: finish executing addx 2 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	91: begin executing addx 6
# During cycle	91: CRT draws pixel in position 10
# Current CRT row: ####....###
# End of cycle	91: finish executing addx 6 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	92: begin executing addx 6
# During cycle	92: CRT draws pixel in position 11
# Current CRT row: ####....####
# End of cycle	92: finish executing addx 6 (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	93: begin executing noop
# During cycle	93: CRT draws pixel in position 12
# Current CRT row: ####....####.
# End of cycle	93: finish executing noop (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	94: begin executing noop
# During cycle	94: CRT draws pixel in position 13
# Current CRT row: ####....####..
# End of cycle	94: finish executing noop (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	95: begin executing noop
# During cycle	95: CRT draws pixel in position 14
# Current CRT row: ####....####...
# End of cycle	95: finish executing noop (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	96: begin executing noop
# During cycle	96: CRT draws pixel in position 15
# Current CRT row: ####....####....
# End of cycle	96: finish executing noop (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	97: begin executing noop
# During cycle	97: CRT draws pixel in position 16
# Current CRT row: ####....####....#
# End of cycle	97: finish executing noop (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	98: begin executing addx 1
# During cycle	98: CRT draws pixel in position 17
# Current CRT row: ####....####....##
# End of cycle	98: finish executing addx 1 (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	99: begin executing addx 1
# During cycle	99: CRT draws pixel in position 18
# Current CRT row: ####....####....###
# End of cycle	99: finish executing addx 1 (Register X is now 18)
#
# Sprite position: .................###....................
# Start cycle	100: begin executing noop
# During cycle	100: CRT draws pixel in position 19
# Current CRT row: ####....####....####
# End of cycle	100: finish executing noop (Register X is now 18)
#
# Sprite position: .................###....................
# Start cycle	101: begin executing noop
# During cycle	101: CRT draws pixel in position 20
# Current CRT row: ####....####....####.
# End of cycle	101: finish executing noop (Register X is now 18)
#
# Sprite position: .................###....................
# Start cycle	102: begin executing addx 7
# During cycle	102: CRT draws pixel in position 21
# Current CRT row: ####....####....####..
# End of cycle	102: finish executing addx 7 (Register X is now 18)
#
# Sprite position: .................###....................
# Start cycle	103: begin executing addx 7
# During cycle	103: CRT draws pixel in position 22
# Current CRT row: ####....####....####...
# End of cycle	103: finish executing addx 7 (Register X is now 25)
#
# Sprite position: ........................###.............
# Start cycle	104: begin executing addx 1
# During cycle	104: CRT draws pixel in position 23
# Current CRT row: ####....####....####....
# End of cycle	104: finish executing addx 1 (Register X is now 25)
#
# Sprite position: ........................###.............
# Start cycle	105: begin executing addx 1
# During cycle	105: CRT draws pixel in position 24
# Current CRT row: ####....####....####....#
# End of cycle	105: finish executing addx 1 (Register X is now 26)
#
# Sprite position: .........................###............
# Start cycle	106: begin executing noop
# During cycle	106: CRT draws pixel in position 25
# Current CRT row: ####....####....####....##
# End of cycle	106: finish executing noop (Register X is now 26)
#
# Sprite position: .........................###............
# Start cycle	107: begin executing addx -13
# During cycle	107: CRT draws pixel in position 26
# Current CRT row: ####....####....####....###
# End of cycle	107: finish executing addx -13 (Register X is now 26)
#
# Sprite position: .........................###............
# Start cycle	108: begin executing addx -13
# During cycle	108: CRT draws pixel in position 27
# Current CRT row: ####....####....####....####
# End of cycle	108: finish executing addx -13 (Register X is now 13)
#
# Sprite position: ............###.........................
# Start cycle	109: begin executing addx 13
# During cycle	109: CRT draws pixel in position 28
# Current CRT row: ####....####....####....####.
# End of cycle	109: finish executing addx 13 (Register X is now 13)
#
# Sprite position: ............###.........................
# Start cycle	110: begin executing addx 13
# During cycle	110: CRT draws pixel in position 29
# Current CRT row: ####....####....####....####..
# End of cycle	110: finish executing addx 13 (Register X is now 26)
#
# Sprite position: .........................###............
# Start cycle	111: begin executing addx 7
# During cycle	111: CRT draws pixel in position 30
# Current CRT row: ####....####....####....####...
# End of cycle	111: finish executing addx 7 (Register X is now 26)
#
# Sprite position: .........................###............
# Start cycle	112: begin executing addx 7
# During cycle	112: CRT draws pixel in position 31
# Current CRT row: ####....####....####....####....
# End of cycle	112: finish executing addx 7 (Register X is now 33)
#
# Sprite position: ................................###.....
# Start cycle	113: begin executing noop
# During cycle	113: CRT draws pixel in position 32
# Current CRT row: ####....####....####....####....#
# End of cycle	113: finish executing noop (Register X is now 33)
#
# Sprite position: ................................###.....
# Start cycle	114: begin executing addx 1
# During cycle	114: CRT draws pixel in position 33
# Current CRT row: ####....####....####....####....##
# End of cycle	114: finish executing addx 1 (Register X is now 33)
#
# Sprite position: ................................###.....
# Start cycle	115: begin executing addx 1
# During cycle	115: CRT draws pixel in position 34
# Current CRT row: ####....####....####....####....###
# End of cycle	115: finish executing addx 1 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	116: begin executing addx -33
# During cycle	116: CRT draws pixel in position 35
# Current CRT row: ####....####....####....####....####
# End of cycle	116: finish executing addx -33 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	117: begin executing addx -33
# During cycle	117: CRT draws pixel in position 36
# Current CRT row: ####....####....####....####....####.
# End of cycle	117: finish executing addx -33 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	118: begin executing noop
# During cycle	118: CRT draws pixel in position 37
# Current CRT row: ####....####....####....####....####..
# End of cycle	118: finish executing noop (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	119: begin executing noop
# During cycle	119: CRT draws pixel in position 38
# Current CRT row: ####....####....####....####....####...
# End of cycle	119: finish executing noop (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	120: begin executing noop
# During cycle	120: CRT draws pixel in position 39
# Current CRT row: ####....####....####....####....####....
# End of cycle	120: finish executing noop (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	121: begin executing addx 2
# During cycle	121: CRT draws pixel in position 0
# Current CRT row: #
# End of cycle	121: finish executing addx 2 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	122: begin executing addx 2
# During cycle	122: CRT draws pixel in position 1
# Current CRT row: ##
# End of cycle	122: finish executing addx 2 (Register X is now 3)
#
# Sprite position: ..###...................................
# Start cycle	123: begin executing noop
# During cycle	123: CRT draws pixel in position 2
# Current CRT row: ###
# End of cycle	123: finish executing noop (Register X is now 3)
#
# Sprite position: ..###...................................
# Start cycle	124: begin executing noop
# During cycle	124: CRT draws pixel in position 3
# Current CRT row: ####
# End of cycle	124: finish executing noop (Register X is now 3)
#
# Sprite position: ..###...................................
# Start cycle	125: begin executing noop
# During cycle	125: CRT draws pixel in position 4
# Current CRT row: #####
# End of cycle	125: finish executing noop (Register X is now 3)
#
# Sprite position: ..###...................................
# Start cycle	126: begin executing addx 8
# During cycle	126: CRT draws pixel in position 5
# Current CRT row: #####.
# End of cycle	126: finish executing addx 8 (Register X is now 3)
#
# Sprite position: ..###...................................
# Start cycle	127: begin executing addx 8
# During cycle	127: CRT draws pixel in position 6
# Current CRT row: #####..
# End of cycle	127: finish executing addx 8 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	128: begin executing noop
# During cycle	128: CRT draws pixel in position 7
# Current CRT row: #####...
# End of cycle	128: finish executing noop (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	129: begin executing addx -1
# During cycle	129: CRT draws pixel in position 8
# Current CRT row: #####....
# End of cycle	129: finish executing addx -1 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	130: begin executing addx -1
# During cycle	130: CRT draws pixel in position 9
# Current CRT row: #####.....
# End of cycle	130: finish executing addx -1 (Register X is now 10)
#
# Sprite position: .........###............................
# Start cycle	131: begin executing addx 2
# During cycle	131: CRT draws pixel in position 10
# Current CRT row: #####.....#
# End of cycle	131: finish executing addx 2 (Register X is now 10)
#
# Sprite position: .........###............................
# Start cycle	132: begin executing addx 2
# During cycle	132: CRT draws pixel in position 11
# Current CRT row: #####.....##
# End of cycle	132: finish executing addx 2 (Register X is now 12)
#
# Sprite position: ...........###..........................
# Start cycle	133: begin executing addx 1
# During cycle	133: CRT draws pixel in position 12
# Current CRT row: #####.....###
# End of cycle	133: finish executing addx 1 (Register X is now 12)
#
# Sprite position: ...........###..........................
# Start cycle	134: begin executing addx 1
# During cycle	134: CRT draws pixel in position 13
# Current CRT row: #####.....####
# End of cycle	134: finish executing addx 1 (Register X is now 13)
#
# Sprite position: ............###.........................
# Start cycle	135: begin executing noop
# During cycle	135: CRT draws pixel in position 14
# Current CRT row: #####.....#####
# End of cycle	135: finish executing noop (Register X is now 13)
#
# Sprite position: ............###.........................
# Start cycle	136: begin executing addx 17
# During cycle	136: CRT draws pixel in position 15
# Current CRT row: #####.....#####.
# End of cycle	136: finish executing addx 17 (Register X is now 13)
#
# Sprite position: ............###.........................
# Start cycle	137: begin executing addx 17
# During cycle	137: CRT draws pixel in position 16
# Current CRT row: #####.....#####..
# End of cycle	137: finish executing addx 17 (Register X is now 30)
#
# Sprite position: .............................###........
# Start cycle	138: begin executing addx -9
# During cycle	138: CRT draws pixel in position 17
# Current CRT row: #####.....#####...
# End of cycle	138: finish executing addx -9 (Register X is now 30)
#
# Sprite position: .............................###........
# Start cycle	139: begin executing addx -9
# During cycle	139: CRT draws pixel in position 18
# Current CRT row: #####.....#####....
# End of cycle	139: finish executing addx -9 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	140: begin executing addx 1
# During cycle	140: CRT draws pixel in position 19
# Current CRT row: #####.....#####.....
# End of cycle	140: finish executing addx 1 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	141: begin executing addx 1
# During cycle	141: CRT draws pixel in position 20
# Current CRT row: #####.....#####.....#
# End of cycle	141: finish executing addx 1 (Register X is now 22)
#
# Sprite position: .....................###................
# Start cycle	142: begin executing addx 1
# During cycle	142: CRT draws pixel in position 21
# Current CRT row: #####.....#####.....##
# End of cycle	142: finish executing addx 1 (Register X is now 22)
#
# Sprite position: .....................###................
# Start cycle	143: begin executing addx 1
# During cycle	143: CRT draws pixel in position 22
# Current CRT row: #####.....#####.....###
# End of cycle	143: finish executing addx 1 (Register X is now 23)
#
# Sprite position: ......................###...............
# Start cycle	144: begin executing addx -3
# During cycle	144: CRT draws pixel in position 23
# Current CRT row: #####.....#####.....####
# End of cycle	144: finish executing addx -3 (Register X is now 23)
#
# Sprite position: ......................###...............
# Start cycle	145: begin executing addx -3
# During cycle	145: CRT draws pixel in position 24
# Current CRT row: #####.....#####.....#####
# End of cycle	145: finish executing addx -3 (Register X is now 20)
#
# Sprite position: ...................###..................
# Start cycle	146: begin executing addx 11
# During cycle	146: CRT draws pixel in position 25
# Current CRT row: #####.....#####.....#####.
# End of cycle	146: finish executing addx 11 (Register X is now 20)
#
# Sprite position: ...................###..................
# Start cycle	147: begin executing addx 11
# During cycle	147: CRT draws pixel in position 26
# Current CRT row: #####.....#####.....#####..
# End of cycle	147: finish executing addx 11 (Register X is now 31)
#
# Sprite position: ..............................###.......
# Start cycle	148: begin executing noop
# During cycle	148: CRT draws pixel in position 27
# Current CRT row: #####.....#####.....#####...
# End of cycle	148: finish executing noop (Register X is now 31)
#
# Sprite position: ..............................###.......
# Start cycle	149: begin executing noop
# During cycle	149: CRT draws pixel in position 28
# Current CRT row: #####.....#####.....#####....
# End of cycle	149: finish executing noop (Register X is now 31)
#
# Sprite position: ..............................###.......
# Start cycle	150: begin executing addx 1
# During cycle	150: CRT draws pixel in position 29
# Current CRT row: #####.....#####.....#####.....
# End of cycle	150: finish executing addx 1 (Register X is now 31)
#
# Sprite position: ..............................###.......
# Start cycle	151: begin executing addx 1
# During cycle	151: CRT draws pixel in position 30
# Current CRT row: #####.....#####.....#####.....#
# End of cycle	151: finish executing addx 1 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	152: begin executing noop
# During cycle	152: CRT draws pixel in position 31
# Current CRT row: #####.....#####.....#####.....##
# End of cycle	152: finish executing noop (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	153: begin executing addx 1
# During cycle	153: CRT draws pixel in position 32
# Current CRT row: #####.....#####.....#####.....###
# End of cycle	153: finish executing addx 1 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	154: begin executing addx 1
# During cycle	154: CRT draws pixel in position 33
# Current CRT row: #####.....#####.....#####.....####
# End of cycle	154: finish executing addx 1 (Register X is now 33)
#
# Sprite position: ................................###.....
# Start cycle	155: begin executing noop
# During cycle	155: CRT draws pixel in position 34
# Current CRT row: #####.....#####.....#####.....#####
# End of cycle	155: finish executing noop (Register X is now 33)
#
# Sprite position: ................................###.....
# Start cycle	156: begin executing noop
# During cycle	156: CRT draws pixel in position 35
# Current CRT row: #####.....#####.....#####.....#####.
# End of cycle	156: finish executing noop (Register X is now 33)
#
# Sprite position: ................................###.....
# Start cycle	157: begin executing addx -13
# During cycle	157: CRT draws pixel in position 36
# Current CRT row: #####.....#####.....#####.....#####..
# End of cycle	157: finish executing addx -13 (Register X is now 33)
#
# Sprite position: ................................###.....
# Start cycle	158: begin executing addx -13
# During cycle	158: CRT draws pixel in position 37
# Current CRT row: #####.....#####.....#####.....#####...
# End of cycle	158: finish executing addx -13 (Register X is now 20)
#
# Sprite position: ...................###..................
# Start cycle	159: begin executing addx -19
# During cycle	159: CRT draws pixel in position 38
# Current CRT row: #####.....#####.....#####.....#####....
# End of cycle	159: finish executing addx -19 (Register X is now 20)
#
# Sprite position: ...................###..................
# Start cycle	160: begin executing addx -19
# During cycle	160: CRT draws pixel in position 39
# Current CRT row: #####.....#####.....#####.....#####.....
# End of cycle	160: finish executing addx -19 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	161: begin executing addx 1
# During cycle	161: CRT draws pixel in position 0
# Current CRT row: #
# End of cycle	161: finish executing addx 1 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	162: begin executing addx 1
# During cycle	162: CRT draws pixel in position 1
# Current CRT row: ##
# End of cycle	162: finish executing addx 1 (Register X is now 2)
#
# Sprite position: .###....................................
# Start cycle	163: begin executing addx 3
# During cycle	163: CRT draws pixel in position 2
# Current CRT row: ###
# End of cycle	163: finish executing addx 3 (Register X is now 2)
#
# Sprite position: .###....................................
# Start cycle	164: begin executing addx 3
# During cycle	164: CRT draws pixel in position 3
# Current CRT row: ####
# End of cycle	164: finish executing addx 3 (Register X is now 5)
#
# Sprite position: ....###.................................
# Start cycle	165: begin executing addx 26
# During cycle	165: CRT draws pixel in position 4
# Current CRT row: #####
# End of cycle	165: finish executing addx 26 (Register X is now 5)
#
# Sprite position: ....###.................................
# Start cycle	166: begin executing addx 26
# During cycle	166: CRT draws pixel in position 5
# Current CRT row: ######
# End of cycle	166: finish executing addx 26 (Register X is now 31)
#
# Sprite position: ..............................###.......
# Start cycle	167: begin executing addx -30
# During cycle	167: CRT draws pixel in position 6
# Current CRT row: ######.
# End of cycle	167: finish executing addx -30 (Register X is now 31)
#
# Sprite position: ..............................###.......
# Start cycle	168: begin executing addx -30
# During cycle	168: CRT draws pixel in position 7
# Current CRT row: ######..
# End of cycle	168: finish executing addx -30 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	169: begin executing addx 12
# During cycle	169: CRT draws pixel in position 8
# Current CRT row: ######...
# End of cycle	169: finish executing addx 12 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	170: begin executing addx 12
# During cycle	170: CRT draws pixel in position 9
# Current CRT row: ######....
# End of cycle	170: finish executing addx 12 (Register X is now 13)
#
# Sprite position: ............###.........................
# Start cycle	171: begin executing addx -1
# During cycle	171: CRT draws pixel in position 10
# Current CRT row: ######.....
# End of cycle	171: finish executing addx -1 (Register X is now 13)
# Sprite position: ............###.........................
# Start cycle	172: begin executing addx -1
# During cycle	172: CRT draws pixel in position 11
# Current CRT row: ######......
# End of cycle	172: finish executing addx -1 (Register X is now 12)
#
# Sprite position: ...........###..........................
# Start cycle	173: begin executing addx 3
# During cycle	173: CRT draws pixel in position 12
# Current CRT row: ######......#
# End of cycle	173: finish executing addx 3 (Register X is now 12)
#
# Sprite position: ...........###..........................
# Start cycle	174: begin executing addx 3
# During cycle	174: CRT draws pixel in position 13
# Current CRT row: ######......##
# End of cycle	174: finish executing addx 3 (Register X is now 15)
#
# Sprite position: ..............###.......................
# Start cycle	175: begin executing addx 1
# During cycle	175: CRT draws pixel in position 14
# Current CRT row: ######......###
# End of cycle	175: finish executing addx 1 (Register X is now 15)
#
# Sprite position: ..............###.......................
# Start cycle	176: begin executing addx 1
# During cycle	176: CRT draws pixel in position 15
# Current CRT row: ######......####
# End of cycle	176: finish executing addx 1 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	177: begin executing noop
# During cycle	177: CRT draws pixel in position 16
# Current CRT row: ######......#####
# End of cycle	177: finish executing noop (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	178: begin executing noop
# During cycle	178: CRT draws pixel in position 17
# Current CRT row: ######......######
# End of cycle	178: finish executing noop (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	179: begin executing noop
# During cycle	179: CRT draws pixel in position 18
# Current CRT row: ######......######.
# End of cycle	179: finish executing noop (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	180: begin executing addx -9
# During cycle	180: CRT draws pixel in position 19
# Current CRT row: ######......######..
# End of cycle	180: finish executing addx -9 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	181: begin executing addx -9
# During cycle	181: CRT draws pixel in position 20
# Current CRT row: ######......######...
# End of cycle	181: finish executing addx -9 (Register X is now 7)
#
# Sprite position: ......###...............................
# Start cycle	182: begin executing addx 18
# During cycle	182: CRT draws pixel in position 21
# Current CRT row: ######......######....
# End of cycle	182: finish executing addx 18 (Register X is now 7)
#
# Sprite position: ......###...............................
# Start cycle	183: begin executing addx 18
# During cycle	183: CRT draws pixel in position 22
# Current CRT row: ######......######.....
# End of cycle	183: finish executing addx 18 (Register X is now 25)
#
# Sprite position: ........................###.............
# Start cycle	184: begin executing addx 1
# During cycle	184: CRT draws pixel in position 23
# Current CRT row: ######......######......
# End of cycle	184: finish executing addx 1 (Register X is now 25)
#
# Sprite position: ........................###.............
# Start cycle	185: begin executing addx 1
# During cycle	185: CRT draws pixel in position 24
# Current CRT row: ######......######......#
# End of cycle	185: finish executing addx 1 (Register X is now 26)
#
# Sprite position: .........................###............
# Start cycle	186: begin executing addx 2
# During cycle	186: CRT draws pixel in position 25
# Current CRT row: ######......######......##
# End of cycle	186: finish executing addx 2 (Register X is now 26)
#
# Sprite position: .........................###............
# Start cycle	187: begin executing addx 2
# During cycle	187: CRT draws pixel in position 26
# Current CRT row: ######......######......###
# End of cycle	187: finish executing addx 2 (Register X is now 28)
#
# Sprite position: ...........................###..........
# Start cycle	188: begin executing noop
# During cycle	188: CRT draws pixel in position 27
# Current CRT row: ######......######......####
# End of cycle	188: finish executing noop (Register X is now 28)
#
# Sprite position: ...........................###..........
# Start cycle	189: begin executing noop
# During cycle	189: CRT draws pixel in position 28
# Current CRT row: ######......######......#####
# End of cycle	189: finish executing noop (Register X is now 28)
#
# Sprite position: ...........................###..........
# Start cycle	190: begin executing addx 9
# During cycle	190: CRT draws pixel in position 29
# Current CRT row: ######......######......######
# End of cycle	190: finish executing addx 9 (Register X is now 28)
#
# Sprite position: ...........................###..........
# Start cycle	191: begin executing addx 9
# During cycle	191: CRT draws pixel in position 30
# Current CRT row: ######......######......######.
# End of cycle	191: finish executing addx 9 (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	192: begin executing noop
# During cycle	192: CRT draws pixel in position 31
# Current CRT row: ######......######......######..
# End of cycle	192: finish executing noop (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	193: begin executing noop
# During cycle	193: CRT draws pixel in position 32
# Current CRT row: ######......######......######...
# End of cycle	193: finish executing noop (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	194: begin executing noop
# During cycle	194: CRT draws pixel in position 33
# Current CRT row: ######......######......######....
# End of cycle	194: finish executing noop (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	195: begin executing addx -1
# During cycle	195: CRT draws pixel in position 34
# Current CRT row: ######......######......######.....
# End of cycle	195: finish executing addx -1 (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	196: begin executing addx -1
# During cycle	196: CRT draws pixel in position 35
# Current CRT row: ######......######......######......
# End of cycle	196: finish executing addx -1 (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	197: begin executing addx 2
# During cycle	197: CRT draws pixel in position 36
# Current CRT row: ######......######......######......#
# End of cycle	197: finish executing addx 2 (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	198: begin executing addx 2
# During cycle	198: CRT draws pixel in position 37
# Current CRT row: ######......######......######......##
# End of cycle	198: finish executing addx 2 (Register X is now 38)
#
# Sprite position: .....................................###
# Start cycle	199: begin executing addx -37
# During cycle	199: CRT draws pixel in position 38
# Current CRT row: ######......######......######......###
# End of cycle	199: finish executing addx -37 (Register X is now 38)
#
# Sprite position: .....................................###
# Start cycle	200: begin executing addx -37
# During cycle	200: CRT draws pixel in position 39
# Current CRT row: ######......######......######......####
# End of cycle	200: finish executing addx -37 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	201: begin executing addx 1
# During cycle	201: CRT draws pixel in position 0
# Current CRT row: #
# End of cycle	201: finish executing addx 1 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	202: begin executing addx 1
# During cycle	202: CRT draws pixel in position 1
# Current CRT row: ##
# End of cycle	202: finish executing addx 1 (Register X is now 2)
#
# Sprite position: .###....................................
# Start cycle	203: begin executing addx 3
# During cycle	203: CRT draws pixel in position 2
# Current CRT row: ###
# End of cycle	203: finish executing addx 3 (Register X is now 2)
#
# Sprite position: .###....................................
# Start cycle	204: begin executing addx 3
# During cycle	204: CRT draws pixel in position 3
# Current CRT row: ####
# End of cycle	204: finish executing addx 3 (Register X is now 5)
#
# Sprite position: ....###.................................
# Start cycle	205: begin executing noop
# During cycle	205: CRT draws pixel in position 4
# Current CRT row: #####
# End of cycle	205: finish executing noop (Register X is now 5)
#
# Sprite position: ....###.................................
# Start cycle	206: begin executing addx 15
# During cycle	206: CRT draws pixel in position 5
# Current CRT row: ######
# End of cycle	206: finish executing addx 15 (Register X is now 5)
#
# Sprite position: ....###.................................
# Start cycle	207: begin executing addx 15
# During cycle	207: CRT draws pixel in position 6
# Current CRT row: #######
# End of cycle	207: finish executing addx 15 (Register X is now 20)
#
# Sprite position: ...................###..................
# Start cycle	208: begin executing addx -21
# During cycle	208: CRT draws pixel in position 7
# Current CRT row: #######.
# End of cycle	208: finish executing addx -21 (Register X is now 20)
#
# Sprite position: ...................###..................
# Start cycle	209: begin executing addx -21
# During cycle	209: CRT draws pixel in position 8
# Current CRT row: #######..
# End of cycle	209: finish executing addx -21 (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	210: begin executing addx 22
# During cycle	210: CRT draws pixel in position 9
# Current CRT row: #######...
# End of cycle	210: finish executing addx 22 (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	211: begin executing addx 22
# During cycle	211: CRT draws pixel in position 10
# Current CRT row: #######....
# End of cycle	211: finish executing addx 22 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	212: begin executing addx -6
# During cycle	212: CRT draws pixel in position 11
# Current CRT row: #######.....
# End of cycle	212: finish executing addx -6 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	213: begin executing addx -6
# During cycle	213: CRT draws pixel in position 12
# Current CRT row: #######......
# End of cycle	213: finish executing addx -6 (Register X is now 15)
#
# Sprite position: ..............###.......................
# Start cycle	214: begin executing addx 1
# During cycle	214: CRT draws pixel in position 13
# Current CRT row: #######.......
# End of cycle	214: finish executing addx 1 (Register X is now 15)
#
# Sprite position: ..............###.......................
# Start cycle	215: begin executing addx 1
# During cycle	215: CRT draws pixel in position 14
# Current CRT row: #######.......#
# End of cycle	215: finish executing addx 1 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	216: begin executing noop
# During cycle	216: CRT draws pixel in position 15
# Current CRT row: #######.......##
# End of cycle	216: finish executing noop (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	217: begin executing addx 2
# During cycle	217: CRT draws pixel in position 16
# Current CRT row: #######.......###
# End of cycle	217: finish executing addx 2 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	218: begin executing addx 2
# During cycle	218: CRT draws pixel in position 17
# Current CRT row: #######.......####
# End of cycle	218: finish executing addx 2 (Register X is now 18)
#
# Sprite position: .................###....................
# Start cycle	219: begin executing addx 1
# During cycle	219: CRT draws pixel in position 18
# Current CRT row: #######.......#####
# End of cycle	219: finish executing addx 1 (Register X is now 18)
#
# Sprite position: .................###....................
# Start cycle	220: begin executing addx 1
# During cycle	220: CRT draws pixel in position 19
# Current CRT row: #######.......######
# End of cycle	220: finish executing addx 1 (Register X is now 19)
#
# Sprite position: ..................###...................
# Start cycle	221: begin executing noop
# During cycle	221: CRT draws pixel in position 20
# Current CRT row: #######.......#######
# End of cycle	221: finish executing noop (Register X is now 19)
#
# Sprite position: ..................###...................
# Start cycle	222: begin executing addx -10
# During cycle	222: CRT draws pixel in position 21
# Current CRT row: #######.......#######.
# End of cycle	222: finish executing addx -10 (Register X is now 19)
#
# Sprite position: ..................###...................
# Start cycle	223: begin executing addx -10
# During cycle	223: CRT draws pixel in position 22
# Current CRT row: #######.......#######..
# End of cycle	223: finish executing addx -10 (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	224: begin executing noop
# During cycle	224: CRT draws pixel in position 23
# Current CRT row: #######.......#######...
# End of cycle	224: finish executing noop (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	225: begin executing noop
# During cycle	225: CRT draws pixel in position 24
# Current CRT row: #######.......#######....
# End of cycle	225: finish executing noop (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	226: begin executing addx 20
# During cycle	226: CRT draws pixel in position 25
# Current CRT row: #######.......#######.....
# End of cycle	226: finish executing addx 20 (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	227: begin executing addx 20
# During cycle	227: CRT draws pixel in position 26
# Current CRT row: #######.......#######......
# End of cycle	227: finish executing addx 20 (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	228: begin executing addx 1
# During cycle	228: CRT draws pixel in position 27
# Current CRT row: #######.......#######.......
# End of cycle	228: finish executing addx 1 (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	229: begin executing addx 1
# During cycle	229: CRT draws pixel in position 28
# Current CRT row: #######.......#######.......#
# End of cycle	229: finish executing addx 1 (Register X is now 30)
#
# Sprite position: .............................###........
# Start cycle	230: begin executing addx 2
# During cycle	230: CRT draws pixel in position 29
# Current CRT row: #######.......#######.......##
# End of cycle	230: finish executing addx 2 (Register X is now 30)
#
# Sprite position: .............................###........
# Start cycle	231: begin executing addx 2
# During cycle	231: CRT draws pixel in position 30
# Current CRT row: #######.......#######.......###
# End of cycle	231: finish executing addx 2 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	232: begin executing addx 2
# During cycle	232: CRT draws pixel in position 31
# Current CRT row: #######.......#######.......####
# End of cycle	232: finish executing addx 2 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	233: begin executing addx 2
# During cycle	233: CRT draws pixel in position 32
# Current CRT row: #######.......#######.......#####
# End of cycle	233: finish executing addx 2 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	234: begin executing addx -6
# During cycle	234: CRT draws pixel in position 33
# Current CRT row: #######.......#######.......######
# End of cycle	234: finish executing addx -6 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	235: begin executing addx -6
# During cycle	235: CRT draws pixel in position 34
# Current CRT row: #######.......#######.......#######
# End of cycle	235: finish executing addx -6 (Register X is now 28)
#
# Sprite position: ...........................###..........
# Start cycle	236: begin executing addx -11
# During cycle	236: CRT draws pixel in position 35
# Current CRT row: #######.......#######.......#######.
# End of cycle	236: finish executing addx -11 (Register X is now 28)
#
# Sprite position: ...........................###..........
# Start cycle	237: begin executing addx -11
# During cycle	237: CRT draws pixel in position 36
# Current CRT row: #######.......#######.......#######..
# End of cycle	237: finish executing addx -11 (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	238: begin executing noop
# During cycle	238: CRT draws pixel in position 37
# Current CRT row: #######.......#######.......#######...
# End of cycle	238: finish executing noop (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	239: begin executing noop
# During cycle	239: CRT draws pixel in position 38
# Current CRT row: #######.......#######.......#######....
# End of cycle	239: finish executing noop (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	240: begin executing noop
# During cycle	240: CRT draws pixel in position 39
# Current CRT row: #######.......#######.......#######.....
# End of cycle	240: finish executing noop (Register X is now 17)
#
# ##..##..##..##..##..##..##..##..##..##..
# ###...###...###...###...###...###...###.
# ####....####....####....####....####....
# #####.....#####.....#####.....#####.....
# ######......######......######......####
# #######.......#######.......#######.....

# %%
instructions = get_input('input.txt')
w = draw_screen(instructions, verbose=True)
print('\n'.join(w))
# Out:
# Sprite position: ###.....................................
# Start cycle	1: begin executing addx 2
# During cycle	1: CRT draws pixel in position 0
# Current CRT row: #
# End of cycle	1: finish executing addx 2 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	2: begin executing addx 2
# During cycle	2: CRT draws pixel in position 1
# Current CRT row: ##
# End of cycle	2: finish executing addx 2 (Register X is now 3)
#
# Sprite position: ..###...................................
# Start cycle	3: begin executing addx 3
# During cycle	3: CRT draws pixel in position 2
# Current CRT row: ###
# End of cycle	3: finish executing addx 3 (Register X is now 3)
#
# Sprite position: ..###...................................
# Start cycle	4: begin executing addx 3
# During cycle	4: CRT draws pixel in position 3
# Current CRT row: ####
# End of cycle	4: finish executing addx 3 (Register X is now 6)
#
# Sprite position: .....###................................
# Start cycle	5: begin executing addx 1
# During cycle	5: CRT draws pixel in position 4
# Current CRT row: ####.
# End of cycle	5: finish executing addx 1 (Register X is now 6)
#
# Sprite position: .....###................................
# Start cycle	6: begin executing addx 1
# During cycle	6: CRT draws pixel in position 5
# Current CRT row: ####.#
# End of cycle	6: finish executing addx 1 (Register X is now 7)
#
# Sprite position: ......###...............................
# Start cycle	7: begin executing noop
# During cycle	7: CRT draws pixel in position 6
# Current CRT row: ####.##
# End of cycle	7: finish executing noop (Register X is now 7)
#
# Sprite position: ......###...............................
# Start cycle	8: begin executing addx 4
# During cycle	8: CRT draws pixel in position 7
# Current CRT row: ####.###
# End of cycle	8: finish executing addx 4 (Register X is now 7)
#
# Sprite position: ......###...............................
# Start cycle	9: begin executing addx 4
# During cycle	9: CRT draws pixel in position 8
# Current CRT row: ####.####
# End of cycle	9: finish executing addx 4 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	10: begin executing addx 1
# During cycle	10: CRT draws pixel in position 9
# Current CRT row: ####.####.
# End of cycle	10: finish executing addx 1 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	11: begin executing addx 1
# During cycle	11: CRT draws pixel in position 10
# Current CRT row: ####.####.#
# End of cycle	11: finish executing addx 1 (Register X is now 12)
#
# Sprite position: ...........###..........................
# Start cycle	12: begin executing noop
# During cycle	12: CRT draws pixel in position 11
# Current CRT row: ####.####.##
# End of cycle	12: finish executing noop (Register X is now 12)
#
# Sprite position: ...........###..........................
# Start cycle	13: begin executing addx 28
# During cycle	13: CRT draws pixel in position 12
# Current CRT row: ####.####.###
# End of cycle	13: finish executing addx 28 (Register X is now 12)
#
# Sprite position: ...........###..........................
# Start cycle	14: begin executing addx 28
# During cycle	14: CRT draws pixel in position 13
# Current CRT row: ####.####.####
# End of cycle	14: finish executing addx 28 (Register X is now 40)
#
# Sprite position: .......................................#
# Start cycle	15: begin executing addx -24
# During cycle	15: CRT draws pixel in position 14
# Current CRT row: ####.####.####.
# End of cycle	15: finish executing addx -24 (Register X is now 40)
#
# Sprite position: .......................................#
# Start cycle	16: begin executing addx -24
# During cycle	16: CRT draws pixel in position 15
# Current CRT row: ####.####.####..
# End of cycle	16: finish executing addx -24 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	17: begin executing noop
# During cycle	17: CRT draws pixel in position 16
# Current CRT row: ####.####.####..#
# End of cycle	17: finish executing noop (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	18: begin executing addx 5
# During cycle	18: CRT draws pixel in position 17
# Current CRT row: ####.####.####..##
# End of cycle	18: finish executing addx 5 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	19: begin executing addx 5
# During cycle	19: CRT draws pixel in position 18
# Current CRT row: ####.####.####..##.
# End of cycle	19: finish executing addx 5 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	20: begin executing addx 17
# During cycle	20: CRT draws pixel in position 19
# Current CRT row: ####.####.####..##..
# End of cycle	20: finish executing addx 17 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	21: begin executing addx 17
# During cycle	21: CRT draws pixel in position 20
# Current CRT row: ####.####.####..##..#
# End of cycle	21: finish executing addx 17 (Register X is now 38)
#
# Sprite position: .....................................###
# Start cycle	22: begin executing addx -16
# During cycle	22: CRT draws pixel in position 21
# Current CRT row: ####.####.####..##..#.
# End of cycle	22: finish executing addx -16 (Register X is now 38)
#
# Sprite position: .....................................###
# Start cycle	23: begin executing addx -16
# During cycle	23: CRT draws pixel in position 22
# Current CRT row: ####.####.####..##..#..
# End of cycle	23: finish executing addx -16 (Register X is now 22)
#
# Sprite position: .....................###................
# Start cycle	24: begin executing noop
# During cycle	24: CRT draws pixel in position 23
# Current CRT row: ####.####.####..##..#..#
# End of cycle	24: finish executing noop (Register X is now 22)
#
# Sprite position: .....................###................
# Start cycle	25: begin executing addx 6
# During cycle	25: CRT draws pixel in position 24
# Current CRT row: ####.####.####..##..#..#.
# End of cycle	25: finish executing addx 6 (Register X is now 22)
#
# Sprite position: .....................###................
# Start cycle	26: begin executing addx 6
# During cycle	26: CRT draws pixel in position 25
# Current CRT row: ####.####.####..##..#..#..
# End of cycle	26: finish executing addx 6 (Register X is now 28)
#
# Sprite position: ...........................###..........
# Start cycle	27: begin executing noop
# During cycle	27: CRT draws pixel in position 26
# Current CRT row: ####.####.####..##..#..#...
# End of cycle	27: finish executing noop (Register X is now 28)
#
# Sprite position: ...........................###..........
# Start cycle	28: begin executing addx -7
# During cycle	28: CRT draws pixel in position 27
# Current CRT row: ####.####.####..##..#..#...#
# End of cycle	28: finish executing addx -7 (Register X is now 28)
#
# Sprite position: ...........................###..........
# Start cycle	29: begin executing addx -7
# During cycle	29: CRT draws pixel in position 28
# Current CRT row: ####.####.####..##..#..#...##
# End of cycle	29: finish executing addx -7 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	30: begin executing addx 11
# During cycle	30: CRT draws pixel in position 29
# Current CRT row: ####.####.####..##..#..#...##.
# End of cycle	30: finish executing addx 11 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	31: begin executing addx 11
# During cycle	31: CRT draws pixel in position 30
# Current CRT row: ####.####.####..##..#..#...##..
# End of cycle	31: finish executing addx 11 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	32: begin executing addx 4
# During cycle	32: CRT draws pixel in position 31
# Current CRT row: ####.####.####..##..#..#...##..#
# End of cycle	32: finish executing addx 4 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	33: begin executing addx 4
# During cycle	33: CRT draws pixel in position 32
# Current CRT row: ####.####.####..##..#..#...##..##
# End of cycle	33: finish executing addx 4 (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	34: begin executing noop
# During cycle	34: CRT draws pixel in position 33
# Current CRT row: ####.####.####..##..#..#...##..##.
# End of cycle	34: finish executing noop (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	35: begin executing addx 1
# During cycle	35: CRT draws pixel in position 34
# Current CRT row: ####.####.####..##..#..#...##..##..
# End of cycle	35: finish executing addx 1 (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	36: begin executing addx 1
# During cycle	36: CRT draws pixel in position 35
# Current CRT row: ####.####.####..##..#..#...##..##..#
# End of cycle	36: finish executing addx 1 (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	37: begin executing addx -36
# During cycle	37: CRT draws pixel in position 36
# Current CRT row: ####.####.####..##..#..#...##..##..##
# End of cycle	37: finish executing addx -36 (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	38: begin executing addx -36
# During cycle	38: CRT draws pixel in position 37
# Current CRT row: ####.####.####..##..#..#...##..##..###
# End of cycle	38: finish executing addx -36 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	39: begin executing addx -2
# During cycle	39: CRT draws pixel in position 38
# Current CRT row: ####.####.####..##..#..#...##..##..###.
# End of cycle	39: finish executing addx -2 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	40: begin executing addx -2
# During cycle	40: CRT draws pixel in position 39
# Current CRT row: ####.####.####..##..#..#...##..##..###..
# End of cycle	40: finish executing addx -2 (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	41: begin executing noop
# During cycle	41: CRT draws pixel in position 0
# Current CRT row: #
# End of cycle	41: finish executing noop (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	42: begin executing noop
# During cycle	42: CRT draws pixel in position 1
# Current CRT row: #.
# End of cycle	42: finish executing noop (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	43: begin executing addx 10
# During cycle	43: CRT draws pixel in position 2
# Current CRT row: #..
# End of cycle	43: finish executing addx 10 (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	44: begin executing addx 10
# During cycle	44: CRT draws pixel in position 3
# Current CRT row: #...
# End of cycle	44: finish executing addx 10 (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	45: begin executing noop
# During cycle	45: CRT draws pixel in position 4
# Current CRT row: #....
# End of cycle	45: finish executing noop (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	46: begin executing noop
# During cycle	46: CRT draws pixel in position 5
# Current CRT row: #.....
# End of cycle	46: finish executing noop (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	47: begin executing addx -2
# During cycle	47: CRT draws pixel in position 6
# Current CRT row: #......
# End of cycle	47: finish executing addx -2 (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	48: begin executing addx -2
# During cycle	48: CRT draws pixel in position 7
# Current CRT row: #.......
# End of cycle	48: finish executing addx -2 (Register X is now 7)
#
# Sprite position: ......###...............................
# Start cycle	49: begin executing addx 2
# During cycle	49: CRT draws pixel in position 8
# Current CRT row: #.......#
# End of cycle	49: finish executing addx 2 (Register X is now 7)
#
# Sprite position: ......###...............................
# Start cycle	50: begin executing addx 2
# During cycle	50: CRT draws pixel in position 9
# Current CRT row: #.......#.
# End of cycle	50: finish executing addx 2 (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	51: begin executing addx 25
# During cycle	51: CRT draws pixel in position 10
# Current CRT row: #.......#.#
# End of cycle	51: finish executing addx 25 (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	52: begin executing addx 25
# During cycle	52: CRT draws pixel in position 11
# Current CRT row: #.......#.#.
# End of cycle	52: finish executing addx 25 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	53: begin executing addx -18
# During cycle	53: CRT draws pixel in position 12
# Current CRT row: #.......#.#..
# End of cycle	53: finish executing addx -18 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	54: begin executing addx -18
# During cycle	54: CRT draws pixel in position 13
# Current CRT row: #.......#.#...
# End of cycle	54: finish executing addx -18 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	55: begin executing addx 23
# During cycle	55: CRT draws pixel in position 14
# Current CRT row: #.......#.#....
# End of cycle	55: finish executing addx 23 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	56: begin executing addx 23
# During cycle	56: CRT draws pixel in position 15
# Current CRT row: #.......#.#....#
# End of cycle	56: finish executing addx 23 (Register X is now 39)
#
# Sprite position: ......................................##
# Start cycle	57: begin executing addx -22
# During cycle	57: CRT draws pixel in position 16
# Current CRT row: #.......#.#....#.
# End of cycle	57: finish executing addx -22 (Register X is now 39)
#
# Sprite position: ......................................##
# Start cycle	58: begin executing addx -22
# During cycle	58: CRT draws pixel in position 17
# Current CRT row: #.......#.#....#..
# End of cycle	58: finish executing addx -22 (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	59: begin executing addx 2
# During cycle	59: CRT draws pixel in position 18
# Current CRT row: #.......#.#....#..#
# End of cycle	59: finish executing addx 2 (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	60: begin executing addx 2
# During cycle	60: CRT draws pixel in position 19
# Current CRT row: #.......#.#....#..#.
# End of cycle	60: finish executing addx 2 (Register X is now 19)
#
# Sprite position: ..................###...................
# Start cycle	61: begin executing addx 5
# During cycle	61: CRT draws pixel in position 20
# Current CRT row: #.......#.#....#..#.#
# End of cycle	61: finish executing addx 5 (Register X is now 19)
#
# Sprite position: ..................###...................
# Start cycle	62: begin executing addx 5
# During cycle	62: CRT draws pixel in position 21
# Current CRT row: #.......#.#....#..#.#.
# End of cycle	62: finish executing addx 5 (Register X is now 24)
#
# Sprite position: .......................###..............
# Start cycle	63: begin executing addx -10
# During cycle	63: CRT draws pixel in position 22
# Current CRT row: #.......#.#....#..#.#..
# End of cycle	63: finish executing addx -10 (Register X is now 24)
#
# Sprite position: .......................###..............
# Start cycle	64: begin executing addx -10
# During cycle	64: CRT draws pixel in position 23
# Current CRT row: #.......#.#....#..#.#..#
# End of cycle	64: finish executing addx -10 (Register X is now 14)
#
# Sprite position: .............###........................
# Start cycle	65: begin executing addx -15
# During cycle	65: CRT draws pixel in position 24
# Current CRT row: #.......#.#....#..#.#..#.
# End of cycle	65: finish executing addx -15 (Register X is now 14)
#
# Sprite position: .............###........................
# Start cycle	66: begin executing addx -15
# During cycle	66: CRT draws pixel in position 25
# Current CRT row: #.......#.#....#..#.#..#..
# End of cycle	66: finish executing addx -15 (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	67: begin executing addx 28
# During cycle	67: CRT draws pixel in position 26
# Current CRT row: #.......#.#....#..#.#..#...
# End of cycle	67: finish executing addx 28 (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	68: begin executing addx 28
# During cycle	68: CRT draws pixel in position 27
# Current CRT row: #.......#.#....#..#.#..#....
# End of cycle	68: finish executing addx 28 (Register X is now 27)
#
# Sprite position: ..........................###...........
# Start cycle	69: begin executing addx 2
# During cycle	69: CRT draws pixel in position 28
# Current CRT row: #.......#.#....#..#.#..#....#
# End of cycle	69: finish executing addx 2 (Register X is now 27)
#
# Sprite position: ..........................###...........
# Start cycle	70: begin executing addx 2
# During cycle	70: CRT draws pixel in position 29
# Current CRT row: #.......#.#....#..#.#..#....#.
# End of cycle	70: finish executing addx 2 (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	71: begin executing addx 5
# During cycle	71: CRT draws pixel in position 30
# Current CRT row: #.......#.#....#..#.#..#....#.#
# End of cycle	71: finish executing addx 5 (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	72: begin executing addx 5
# During cycle	72: CRT draws pixel in position 31
# Current CRT row: #.......#.#....#..#.#..#....#.#.
# End of cycle	72: finish executing addx 5 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	73: begin executing addx 2
# During cycle	73: CRT draws pixel in position 32
# Current CRT row: #.......#.#....#..#.#..#....#.#..
# End of cycle	73: finish executing addx 2 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	74: begin executing addx 2
# During cycle	74: CRT draws pixel in position 33
# Current CRT row: #.......#.#....#..#.#..#....#.#..#
# End of cycle	74: finish executing addx 2 (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	75: begin executing addx -16
# During cycle	75: CRT draws pixel in position 34
# Current CRT row: #.......#.#....#..#.#..#....#.#..#.
# End of cycle	75: finish executing addx -16 (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	76: begin executing addx -16
# During cycle	76: CRT draws pixel in position 35
# Current CRT row: #.......#.#....#..#.#..#....#.#..#.#
# End of cycle	76: finish executing addx -16 (Register X is now 20)
#
# Sprite position: ...................###..................
# Start cycle	77: begin executing addx 17
# During cycle	77: CRT draws pixel in position 36
# Current CRT row: #.......#.#....#..#.#..#....#.#..#.#.
# End of cycle	77: finish executing addx 17 (Register X is now 20)
#
# Sprite position: ...................###..................
# Start cycle	78: begin executing addx 17
# During cycle	78: CRT draws pixel in position 37
# Current CRT row: #.......#.#....#..#.#..#....#.#..#.#..
# End of cycle	78: finish executing addx 17 (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	79: begin executing addx -36
# During cycle	79: CRT draws pixel in position 38
# Current CRT row: #.......#.#....#..#.#..#....#.#..#.#..#
# End of cycle	79: finish executing addx -36 (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	80: begin executing addx -36
# During cycle	80: CRT draws pixel in position 39
# Current CRT row: #.......#.#....#..#.#..#....#.#..#.#..#.
# End of cycle	80: finish executing addx -36 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	81: begin executing noop
# During cycle	81: CRT draws pixel in position 0
# Current CRT row: #
# End of cycle	81: finish executing noop (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	82: begin executing noop
# During cycle	82: CRT draws pixel in position 1
# Current CRT row: ##
# End of cycle	82: finish executing noop (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	83: begin executing addx 39
# During cycle	83: CRT draws pixel in position 2
# Current CRT row: ###
# End of cycle	83: finish executing addx 39 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	84: begin executing addx 39
# During cycle	84: CRT draws pixel in position 3
# Current CRT row: ###.
# End of cycle	84: finish executing addx 39 (Register X is now 40)
# Sprite position: .......................................#
# Start cycle	85: begin executing addx -32
# During cycle	85: CRT draws pixel in position 4
# Current CRT row: ###..
# End of cycle	85: finish executing addx -32 (Register X is now 40)
#
# Sprite position: .......................................#
# Start cycle	86: begin executing addx -32
# During cycle	86: CRT draws pixel in position 5
# Current CRT row: ###...
# End of cycle	86: finish executing addx -32 (Register X is now 8)
#
# Sprite position: .......###..............................
# Start cycle	87: begin executing addx -5
# During cycle	87: CRT draws pixel in position 6
# Current CRT row: ###....
# End of cycle	87: finish executing addx -5 (Register X is now 8)
#
# Sprite position: .......###..............................
# Start cycle	88: begin executing addx -5
# During cycle	88: CRT draws pixel in position 7
# Current CRT row: ###....#
# End of cycle	88: finish executing addx -5 (Register X is now 3)
#
# Sprite position: ..###...................................
# Start cycle	89: begin executing addx 7
# During cycle	89: CRT draws pixel in position 8
# Current CRT row: ###....#.
# End of cycle	89: finish executing addx 7 (Register X is now 3)
#
# Sprite position: ..###...................................
# Start cycle	90: begin executing addx 7
# During cycle	90: CRT draws pixel in position 9
# Current CRT row: ###....#..
# End of cycle	90: finish executing addx 7 (Register X is now 10)
#
# Sprite position: .........###............................
# Start cycle	91: begin executing addx 1
# During cycle	91: CRT draws pixel in position 10
# Current CRT row: ###....#..#
# End of cycle	91: finish executing addx 1 (Register X is now 10)
#
# Sprite position: .........###............................
# Start cycle	92: begin executing addx 1
# During cycle	92: CRT draws pixel in position 11
# Current CRT row: ###....#..##
# End of cycle	92: finish executing addx 1 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	93: begin executing addx 5
# During cycle	93: CRT draws pixel in position 12
# Current CRT row: ###....#..###
# End of cycle	93: finish executing addx 5 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	94: begin executing addx 5
# During cycle	94: CRT draws pixel in position 13
# Current CRT row: ###....#..###.
# End of cycle	94: finish executing addx 5 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	95: begin executing addx -13
# During cycle	95: CRT draws pixel in position 14
# Current CRT row: ###....#..###..
# End of cycle	95: finish executing addx -13 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	96: begin executing addx -13
# During cycle	96: CRT draws pixel in position 15
# Current CRT row: ###....#..###..#
# End of cycle	96: finish executing addx -13 (Register X is now 3)
#
# Sprite position: ..###...................................
# Start cycle	97: begin executing addx 1
# During cycle	97: CRT draws pixel in position 16
# Current CRT row: ###....#..###..#.
# End of cycle	97: finish executing addx 1 (Register X is now 3)
#
# Sprite position: ..###...................................
# Start cycle	98: begin executing addx 1
# During cycle	98: CRT draws pixel in position 17
# Current CRT row: ###....#..###..#..
# End of cycle	98: finish executing addx 1 (Register X is now 4)
#
# Sprite position: ...###..................................
# Start cycle	99: begin executing addx 17
# During cycle	99: CRT draws pixel in position 18
# Current CRT row: ###....#..###..#...
# End of cycle	99: finish executing addx 17 (Register X is now 4)
#
# Sprite position: ...###..................................
# Start cycle	100: begin executing addx 17
# During cycle	100: CRT draws pixel in position 19
# Current CRT row: ###....#..###..#....
# End of cycle	100: finish executing addx 17 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	101: begin executing addx 1
# During cycle	101: CRT draws pixel in position 20
# Current CRT row: ###....#..###..#....#
# End of cycle	101: finish executing addx 1 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	102: begin executing addx 1
# During cycle	102: CRT draws pixel in position 21
# Current CRT row: ###....#..###..#....##
# End of cycle	102: finish executing addx 1 (Register X is now 22)
#
# Sprite position: .....................###................
# Start cycle	103: begin executing noop
# During cycle	103: CRT draws pixel in position 22
# Current CRT row: ###....#..###..#....###
# End of cycle	103: finish executing noop (Register X is now 22)
#
# Sprite position: .....................###................
# Start cycle	104: begin executing addx 7
# During cycle	104: CRT draws pixel in position 23
# Current CRT row: ###....#..###..#....####
# End of cycle	104: finish executing addx 7 (Register X is now 22)
#
# Sprite position: .....................###................
# Start cycle	105: begin executing addx 7
# During cycle	105: CRT draws pixel in position 24
# Current CRT row: ###....#..###..#....####.
# End of cycle	105: finish executing addx 7 (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	106: begin executing noop
# During cycle	106: CRT draws pixel in position 25
# Current CRT row: ###....#..###..#....####..
# End of cycle	106: finish executing noop (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	107: begin executing addx -2
# During cycle	107: CRT draws pixel in position 26
# Current CRT row: ###....#..###..#....####...
# End of cycle	107: finish executing addx -2 (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	108: begin executing addx -2
# During cycle	108: CRT draws pixel in position 27
# Current CRT row: ###....#..###..#....####....
# End of cycle	108: finish executing addx -2 (Register X is now 27)
#
# Sprite position: ..........................###...........
# Start cycle	109: begin executing addx 2
# During cycle	109: CRT draws pixel in position 28
# Current CRT row: ###....#..###..#....####....#
# End of cycle	109: finish executing addx 2 (Register X is now 27)
#
# Sprite position: ..........................###...........
# Start cycle	110: begin executing addx 2
# During cycle	110: CRT draws pixel in position 29
# Current CRT row: ###....#..###..#....####....#.
# End of cycle	110: finish executing addx 2 (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	111: begin executing addx 5
# During cycle	111: CRT draws pixel in position 30
# Current CRT row: ###....#..###..#....####....#.#
# End of cycle	111: finish executing addx 5 (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	112: begin executing addx 5
# During cycle	112: CRT draws pixel in position 31
# Current CRT row: ###....#..###..#....####....#.#.
# End of cycle	112: finish executing addx 5 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	113: begin executing addx 2
# During cycle	113: CRT draws pixel in position 32
# Current CRT row: ###....#..###..#....####....#.#..
# End of cycle	113: finish executing addx 2 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	114: begin executing addx 2
# During cycle	114: CRT draws pixel in position 33
# Current CRT row: ###....#..###..#....####....#.#..#
# End of cycle	114: finish executing addx 2 (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	115: begin executing noop
# During cycle	115: CRT draws pixel in position 34
# Current CRT row: ###....#..###..#....####....#.#..#.
# End of cycle	115: finish executing noop (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	116: begin executing noop
# During cycle	116: CRT draws pixel in position 35
# Current CRT row: ###....#..###..#....####....#.#..#.#
# End of cycle	116: finish executing noop (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	117: begin executing noop
# During cycle	117: CRT draws pixel in position 36
# Current CRT row: ###....#..###..#....####....#.#..#.##
# End of cycle	117: finish executing noop (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	118: begin executing noop
# During cycle	118: CRT draws pixel in position 37
# Current CRT row: ###....#..###..#....####....#.#..#.###
# End of cycle	118: finish executing noop (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	119: begin executing addx -37
# During cycle	119: CRT draws pixel in position 38
# Current CRT row: ###....#..###..#....####....#.#..#.###.
# End of cycle	119: finish executing addx -37 (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	120: begin executing addx -37
# During cycle	120: CRT draws pixel in position 39
# Current CRT row: ###....#..###..#....####....#.#..#.###..
# End of cycle	120: finish executing addx -37 (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	121: begin executing noop
# During cycle	121: CRT draws pixel in position 0
# Current CRT row: #
# End of cycle	121: finish executing noop (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	122: begin executing noop
# During cycle	122: CRT draws pixel in position 1
# Current CRT row: #.
# End of cycle	122: finish executing noop (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	123: begin executing noop
# During cycle	123: CRT draws pixel in position 2
# Current CRT row: #..
# End of cycle	123: finish executing noop (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	124: begin executing noop
# During cycle	124: CRT draws pixel in position 3
# Current CRT row: #...
# End of cycle	124: finish executing noop (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	125: begin executing addx 6
# During cycle	125: CRT draws pixel in position 4
# Current CRT row: #....
# End of cycle	125: finish executing addx 6 (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	126: begin executing addx 6
# During cycle	126: CRT draws pixel in position 5
# Current CRT row: #.....
# End of cycle	126: finish executing addx 6 (Register X is now 5)
#
# Sprite position: ....###.................................
# Start cycle	127: begin executing addx 11
# During cycle	127: CRT draws pixel in position 6
# Current CRT row: #.....#
# End of cycle	127: finish executing addx 11 (Register X is now 5)
#
# Sprite position: ....###.................................
# Start cycle	128: begin executing addx 11
# During cycle	128: CRT draws pixel in position 7
# Current CRT row: #.....#.
# End of cycle	128: finish executing addx 11 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	129: begin executing addx -7
# During cycle	129: CRT draws pixel in position 8
# Current CRT row: #.....#..
# End of cycle	129: finish executing addx -7 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	130: begin executing addx -7
# During cycle	130: CRT draws pixel in position 9
# Current CRT row: #.....#...
# End of cycle	130: finish executing addx -7 (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	131: begin executing addx 29
# During cycle	131: CRT draws pixel in position 10
# Current CRT row: #.....#...#
# End of cycle	131: finish executing addx 29 (Register X is now 9)
#
# Sprite position: ........###.............................
# Start cycle	132: begin executing addx 29
# During cycle	132: CRT draws pixel in position 11
# Current CRT row: #.....#...#.
# End of cycle	132: finish executing addx 29 (Register X is now 38)
#
# Sprite position: .....................................###
# Start cycle	133: begin executing addx -22
# During cycle	133: CRT draws pixel in position 12
# Current CRT row: #.....#...#..
# End of cycle	133: finish executing addx -22 (Register X is now 38)
#
# Sprite position: .....................................###
# Start cycle	134: begin executing addx -22
# During cycle	134: CRT draws pixel in position 13
# Current CRT row: #.....#...#...
# End of cycle	134: finish executing addx -22 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	135: begin executing addx 5
# During cycle	135: CRT draws pixel in position 14
# Current CRT row: #.....#...#....
# End of cycle	135: finish executing addx 5 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	136: begin executing addx 5
# During cycle	136: CRT draws pixel in position 15
# Current CRT row: #.....#...#....#
# End of cycle	136: finish executing addx 5 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	137: begin executing noop
# During cycle	137: CRT draws pixel in position 16
# Current CRT row: #.....#...#....#.
# End of cycle	137: finish executing noop (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	138: begin executing noop
# During cycle	138: CRT draws pixel in position 17
# Current CRT row: #.....#...#....#..
# End of cycle	138: finish executing noop (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	139: begin executing noop
# During cycle	139: CRT draws pixel in position 18
# Current CRT row: #.....#...#....#...
# End of cycle	139: finish executing noop (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	140: begin executing addx 3
# During cycle	140: CRT draws pixel in position 19
# Current CRT row: #.....#...#....#....
# End of cycle	140: finish executing addx 3 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	141: begin executing addx 3
# During cycle	141: CRT draws pixel in position 20
# Current CRT row: #.....#...#....#....#
# End of cycle	141: finish executing addx 3 (Register X is now 24)
#
# Sprite position: .......................###..............
# Start cycle	142: begin executing noop
# During cycle	142: CRT draws pixel in position 21
# Current CRT row: #.....#...#....#....#.
# End of cycle	142: finish executing noop (Register X is now 24)
#
# Sprite position: .......................###..............
# Start cycle	143: begin executing addx 7
# During cycle	143: CRT draws pixel in position 22
# Current CRT row: #.....#...#....#....#..
# End of cycle	143: finish executing addx 7 (Register X is now 24)
#
# Sprite position: .......................###..............
# Start cycle	144: begin executing addx 7
# During cycle	144: CRT draws pixel in position 23
# Current CRT row: #.....#...#....#....#..#
# End of cycle	144: finish executing addx 7 (Register X is now 31)
#
# Sprite position: ..............................###.......
# Start cycle	145: begin executing addx -28
# During cycle	145: CRT draws pixel in position 24
# Current CRT row: #.....#...#....#....#..#.
# End of cycle	145: finish executing addx -28 (Register X is now 31)
#
# Sprite position: ..............................###.......
# Start cycle	146: begin executing addx -28
# During cycle	146: CRT draws pixel in position 25
# Current CRT row: #.....#...#....#....#..#..
# End of cycle	146: finish executing addx -28 (Register X is now 3)
#
# Sprite position: ..###...................................
# Start cycle	147: begin executing addx 24
# During cycle	147: CRT draws pixel in position 26
# Current CRT row: #.....#...#....#....#..#...
# End of cycle	147: finish executing addx 24 (Register X is now 3)
#
# Sprite position: ..###...................................
# Start cycle	148: begin executing addx 24
# During cycle	148: CRT draws pixel in position 27
# Current CRT row: #.....#...#....#....#..#....
# End of cycle	148: finish executing addx 24 (Register X is now 27)
#
# Sprite position: ..........................###...........
# Start cycle	149: begin executing addx 3
# During cycle	149: CRT draws pixel in position 28
# Current CRT row: #.....#...#....#....#..#....#
# End of cycle	149: finish executing addx 3 (Register X is now 27)
#
# Sprite position: ..........................###...........
# Start cycle	150: begin executing addx 3
# During cycle	150: CRT draws pixel in position 29
# Current CRT row: #.....#...#....#....#..#....#.
# End of cycle	150: finish executing addx 3 (Register X is now 30)
#
# Sprite position: .............................###........
# Start cycle	151: begin executing addx 2
# During cycle	151: CRT draws pixel in position 30
# Current CRT row: #.....#...#....#....#..#....#.#
# End of cycle	151: finish executing addx 2 (Register X is now 30)
#
# Sprite position: .............................###........
# Start cycle	152: begin executing addx 2
# During cycle	152: CRT draws pixel in position 31
# Current CRT row: #.....#...#....#....#..#....#.##
# End of cycle	152: finish executing addx 2 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	153: begin executing noop
# During cycle	153: CRT draws pixel in position 32
# Current CRT row: #.....#...#....#....#..#....#.###
# End of cycle	153: finish executing noop (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	154: begin executing addx 2
# During cycle	154: CRT draws pixel in position 33
# Current CRT row: #.....#...#....#....#..#....#.####
# End of cycle	154: finish executing addx 2 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	155: begin executing addx 2
# During cycle	155: CRT draws pixel in position 34
# Current CRT row: #.....#...#....#....#..#....#.####.
# End of cycle	155: finish executing addx 2 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	156: begin executing noop
# During cycle	156: CRT draws pixel in position 35
# Current CRT row: #.....#...#....#....#..#....#.####.#
# End of cycle	156: finish executing noop (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	157: begin executing addx 3
# During cycle	157: CRT draws pixel in position 36
# Current CRT row: #.....#...#....#....#..#....#.####.#.
# End of cycle	157: finish executing addx 3 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	158: begin executing addx 3
# During cycle	158: CRT draws pixel in position 37
# Current CRT row: #.....#...#....#....#..#....#.####.#..
# End of cycle	158: finish executing addx 3 (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	159: begin executing addx -38
# During cycle	159: CRT draws pixel in position 38
# Current CRT row: #.....#...#....#....#..#....#.####.#..#
# End of cycle	159: finish executing addx -38 (Register X is now 37)
#
# Sprite position: ....................................###.
# Start cycle	160: begin executing addx -38
# During cycle	160: CRT draws pixel in position 39
# Current CRT row: #.....#...#....#....#..#....#.####.#..#.
# End of cycle	160: finish executing addx -38 (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	161: begin executing noop
# During cycle	161: CRT draws pixel in position 0
# Current CRT row: #
# End of cycle	161: finish executing noop (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	162: begin executing addx 7
# During cycle	162: CRT draws pixel in position 1
# Current CRT row: #.
# End of cycle	162: finish executing addx 7 (Register X is now -1)
#
# Sprite position: #.......................................
# Start cycle	163: begin executing addx 7
# During cycle	163: CRT draws pixel in position 2
# Current CRT row: #..
# End of cycle	163: finish executing addx 7 (Register X is now 6)
#
# Sprite position: .....###................................
# Start cycle	164: begin executing addx -2
# During cycle	164: CRT draws pixel in position 3
# Current CRT row: #...
# End of cycle	164: finish executing addx -2 (Register X is now 6)
#
# Sprite position: .....###................................
# Start cycle	165: begin executing addx -2
# During cycle	165: CRT draws pixel in position 4
# Current CRT row: #....
# End of cycle	165: finish executing addx -2 (Register X is now 4)
#
# Sprite position: ...###..................................
# Start cycle	166: begin executing addx 1
# During cycle	166: CRT draws pixel in position 5
# Current CRT row: #....#
# End of cycle	166: finish executing addx 1 (Register X is now 4)
#
# Sprite position: ...###..................................
# Start cycle	167: begin executing addx 1
# During cycle	167: CRT draws pixel in position 6
# Current CRT row: #....#.
# End of cycle	167: finish executing addx 1 (Register X is now 5)
# Sprite position: ....###.................................
# Start cycle	168: begin executing addx 6
# During cycle	168: CRT draws pixel in position 7
# Current CRT row: #....#..
# End of cycle	168: finish executing addx 6 (Register X is now 5)
#
# Sprite position: ....###.................................
# Start cycle	169: begin executing addx 6
# During cycle	169: CRT draws pixel in position 8
# Current CRT row: #....#...
# End of cycle	169: finish executing addx 6 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	170: begin executing addx -10
# During cycle	170: CRT draws pixel in position 9
# Current CRT row: #....#....
# End of cycle	170: finish executing addx -10 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	171: begin executing addx -10
# During cycle	171: CRT draws pixel in position 10
# Current CRT row: #....#....#
# End of cycle	171: finish executing addx -10 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	172: begin executing addx 38
# During cycle	172: CRT draws pixel in position 11
# Current CRT row: #....#....#.
# End of cycle	172: finish executing addx 38 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	173: begin executing addx 38
# During cycle	173: CRT draws pixel in position 12
# Current CRT row: #....#....#..
# End of cycle	173: finish executing addx 38 (Register X is now 39)
#
# Sprite position: ......................................##
# Start cycle	174: begin executing addx -25
# During cycle	174: CRT draws pixel in position 13
# Current CRT row: #....#....#...
# End of cycle	174: finish executing addx -25 (Register X is now 39)
#
# Sprite position: ......................................##
# Start cycle	175: begin executing addx -25
# During cycle	175: CRT draws pixel in position 14
# Current CRT row: #....#....#....
# End of cycle	175: finish executing addx -25 (Register X is now 14)
#
# Sprite position: .............###........................
# Start cycle	176: begin executing addx 5
# During cycle	176: CRT draws pixel in position 15
# Current CRT row: #....#....#....#
# End of cycle	176: finish executing addx 5 (Register X is now 14)
#
# Sprite position: .............###........................
# Start cycle	177: begin executing addx 5
# During cycle	177: CRT draws pixel in position 16
# Current CRT row: #....#....#....#.
# End of cycle	177: finish executing addx 5 (Register X is now 19)
#
# Sprite position: ..................###...................
# Start cycle	178: begin executing addx 2
# During cycle	178: CRT draws pixel in position 17
# Current CRT row: #....#....#....#..
# End of cycle	178: finish executing addx 2 (Register X is now 19)
#
# Sprite position: ..................###...................
# Start cycle	179: begin executing addx 2
# During cycle	179: CRT draws pixel in position 18
# Current CRT row: #....#....#....#..#
# End of cycle	179: finish executing addx 2 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	180: begin executing addx -10
# During cycle	180: CRT draws pixel in position 19
# Current CRT row: #....#....#....#..#.
# End of cycle	180: finish executing addx -10 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	181: begin executing addx -10
# During cycle	181: CRT draws pixel in position 20
# Current CRT row: #....#....#....#..#.#
# End of cycle	181: finish executing addx -10 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	182: begin executing addx 11
# During cycle	182: CRT draws pixel in position 21
# Current CRT row: #....#....#....#..#.#.
# End of cycle	182: finish executing addx 11 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	183: begin executing addx 11
# During cycle	183: CRT draws pixel in position 22
# Current CRT row: #....#....#....#..#.#..
# End of cycle	183: finish executing addx 11 (Register X is now 22)
#
# Sprite position: .....................###................
# Start cycle	184: begin executing addx 2
# During cycle	184: CRT draws pixel in position 23
# Current CRT row: #....#....#....#..#.#..#
# End of cycle	184: finish executing addx 2 (Register X is now 22)
#
# Sprite position: .....................###................
# Start cycle	185: begin executing addx 2
# During cycle	185: CRT draws pixel in position 24
# Current CRT row: #....#....#....#..#.#..#.
# End of cycle	185: finish executing addx 2 (Register X is now 24)
#
# Sprite position: .......................###..............
# Start cycle	186: begin executing noop
# During cycle	186: CRT draws pixel in position 25
# Current CRT row: #....#....#....#..#.#..#.#
# End of cycle	186: finish executing noop (Register X is now 24)
#
# Sprite position: .......................###..............
# Start cycle	187: begin executing addx 3
# During cycle	187: CRT draws pixel in position 26
# Current CRT row: #....#....#....#..#.#..#.#.
# End of cycle	187: finish executing addx 3 (Register X is now 24)
#
# Sprite position: .......................###..............
# Start cycle	188: begin executing addx 3
# During cycle	188: CRT draws pixel in position 27
# Current CRT row: #....#....#....#..#.#..#.#..
# End of cycle	188: finish executing addx 3 (Register X is now 27)
#
# Sprite position: ..........................###...........
# Start cycle	189: begin executing addx 2
# During cycle	189: CRT draws pixel in position 28
# Current CRT row: #....#....#....#..#.#..#.#..#
# End of cycle	189: finish executing addx 2 (Register X is now 27)
#
# Sprite position: ..........................###...........
# Start cycle	190: begin executing addx 2
# During cycle	190: CRT draws pixel in position 29
# Current CRT row: #....#....#....#..#.#..#.#..#.
# End of cycle	190: finish executing addx 2 (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	191: begin executing noop
# During cycle	191: CRT draws pixel in position 30
# Current CRT row: #....#....#....#..#.#..#.#..#.#
# End of cycle	191: finish executing noop (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	192: begin executing addx 3
# During cycle	192: CRT draws pixel in position 31
# Current CRT row: #....#....#....#..#.#..#.#..#.#.
# End of cycle	192: finish executing addx 3 (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	193: begin executing addx 3
# During cycle	193: CRT draws pixel in position 32
# Current CRT row: #....#....#....#..#.#..#.#..#.#..
# End of cycle	193: finish executing addx 3 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	194: begin executing addx 2
# During cycle	194: CRT draws pixel in position 33
# Current CRT row: #....#....#....#..#.#..#.#..#.#..#
# End of cycle	194: finish executing addx 2 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	195: begin executing addx 2
# During cycle	195: CRT draws pixel in position 34
# Current CRT row: #....#....#....#..#.#..#.#..#.#..#.
# End of cycle	195: finish executing addx 2 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	196: begin executing addx 5
# During cycle	196: CRT draws pixel in position 35
# Current CRT row: #....#....#....#..#.#..#.#..#.#..#.#
# End of cycle	196: finish executing addx 5 (Register X is now 34)
#
# Sprite position: .................................###....
# Start cycle	197: begin executing addx 5
# During cycle	197: CRT draws pixel in position 36
# Current CRT row: #....#....#....#..#.#..#.#..#.#..#.#.
# End of cycle	197: finish executing addx 5 (Register X is now 39)
#
# Sprite position: ......................................##
# Start cycle	198: begin executing addx -39
# During cycle	198: CRT draws pixel in position 37
# Current CRT row: #....#....#....#..#.#..#.#..#.#..#.#..
# End of cycle	198: finish executing addx -39 (Register X is now 39)
#
# Sprite position: ......................................##
# Start cycle	199: begin executing addx -39
# During cycle	199: CRT draws pixel in position 38
# Current CRT row: #....#....#....#..#.#..#.#..#.#..#.#..#
# End of cycle	199: finish executing addx -39 (Register X is now 0)
#
# Sprite position: ##......................................
# Start cycle	200: begin executing addx 1
# During cycle	200: CRT draws pixel in position 39
# Current CRT row: #....#....#....#..#.#..#.#..#.#..#.#..#.
# End of cycle	200: finish executing addx 1 (Register X is now 0)
#
# Sprite position: ##......................................
# Start cycle	201: begin executing addx 1
# During cycle	201: CRT draws pixel in position 0
# Current CRT row: #
# End of cycle	201: finish executing addx 1 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	202: begin executing addx 1
# During cycle	202: CRT draws pixel in position 1
# Current CRT row: ##
# End of cycle	202: finish executing addx 1 (Register X is now 1)
#
# Sprite position: ###.....................................
# Start cycle	203: begin executing addx 1
# During cycle	203: CRT draws pixel in position 2
# Current CRT row: ###
# End of cycle	203: finish executing addx 1 (Register X is now 2)
#
# Sprite position: .###....................................
# Start cycle	204: begin executing addx 3
# During cycle	204: CRT draws pixel in position 3
# Current CRT row: ####
# End of cycle	204: finish executing addx 3 (Register X is now 2)
#
# Sprite position: .###....................................
# Start cycle	205: begin executing addx 3
# During cycle	205: CRT draws pixel in position 4
# Current CRT row: ####.
# End of cycle	205: finish executing addx 3 (Register X is now 5)
#
# Sprite position: ....###.................................
# Start cycle	206: begin executing addx 2
# During cycle	206: CRT draws pixel in position 5
# Current CRT row: ####.#
# End of cycle	206: finish executing addx 2 (Register X is now 5)
#
# Sprite position: ....###.................................
# Start cycle	207: begin executing addx 2
# During cycle	207: CRT draws pixel in position 6
# Current CRT row: ####.##
# End of cycle	207: finish executing addx 2 (Register X is now 7)
#
# Sprite position: ......###...............................
# Start cycle	208: begin executing addx 4
# During cycle	208: CRT draws pixel in position 7
# Current CRT row: ####.###
# End of cycle	208: finish executing addx 4 (Register X is now 7)
#
# Sprite position: ......###...............................
# Start cycle	209: begin executing addx 4
# During cycle	209: CRT draws pixel in position 8
# Current CRT row: ####.####
# End of cycle	209: finish executing addx 4 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	210: begin executing addx 29
# During cycle	210: CRT draws pixel in position 9
# Current CRT row: ####.####.
# End of cycle	210: finish executing addx 29 (Register X is now 11)
#
# Sprite position: ..........###...........................
# Start cycle	211: begin executing addx 29
# During cycle	211: CRT draws pixel in position 10
# Current CRT row: ####.####.#
# End of cycle	211: finish executing addx 29 (Register X is now 40)
#
# Sprite position: .......................................#
# Start cycle	212: begin executing addx -23
# During cycle	212: CRT draws pixel in position 11
# Current CRT row: ####.####.#.
# End of cycle	212: finish executing addx -23 (Register X is now 40)
#
# Sprite position: .......................................#
# Start cycle	213: begin executing addx -23
# During cycle	213: CRT draws pixel in position 12
# Current CRT row: ####.####.#..
# End of cycle	213: finish executing addx -23 (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	214: begin executing noop
# During cycle	214: CRT draws pixel in position 13
# Current CRT row: ####.####.#...
# End of cycle	214: finish executing noop (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	215: begin executing addx -1
# During cycle	215: CRT draws pixel in position 14
# Current CRT row: ####.####.#....
# End of cycle	215: finish executing addx -1 (Register X is now 17)
#
# Sprite position: ................###.....................
# Start cycle	216: begin executing addx -1
# During cycle	216: CRT draws pixel in position 15
# Current CRT row: ####.####.#.....
# End of cycle	216: finish executing addx -1 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	217: begin executing addx 5
# During cycle	217: CRT draws pixel in position 16
# Current CRT row: ####.####.#.....#
# End of cycle	217: finish executing addx 5 (Register X is now 16)
#
# Sprite position: ...............###......................
# Start cycle	218: begin executing addx 5
# During cycle	218: CRT draws pixel in position 17
# Current CRT row: ####.####.#.....##
# End of cycle	218: finish executing addx 5 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	219: begin executing noop
# During cycle	219: CRT draws pixel in position 18
# Current CRT row: ####.####.#.....##.
# End of cycle	219: finish executing noop (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	220: begin executing addx 11
# During cycle	220: CRT draws pixel in position 19
# Current CRT row: ####.####.#.....##..
# End of cycle	220: finish executing addx 11 (Register X is now 21)
#
# Sprite position: ....................###.................
# Start cycle	221: begin executing addx 11
# During cycle	221: CRT draws pixel in position 20
# Current CRT row: ####.####.#.....##..#
# End of cycle	221: finish executing addx 11 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	222: begin executing addx -10
# During cycle	222: CRT draws pixel in position 21
# Current CRT row: ####.####.#.....##..#.
# End of cycle	222: finish executing addx -10 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	223: begin executing addx -10
# During cycle	223: CRT draws pixel in position 22
# Current CRT row: ####.####.#.....##..#..
# End of cycle	223: finish executing addx -10 (Register X is now 22)
#
# Sprite position: .....................###................
# Start cycle	224: begin executing addx 5
# During cycle	224: CRT draws pixel in position 23
# Current CRT row: ####.####.#.....##..#..#
# End of cycle	224: finish executing addx 5 (Register X is now 22)
#
# Sprite position: .....................###................
# Start cycle	225: begin executing addx 5
# During cycle	225: CRT draws pixel in position 24
# Current CRT row: ####.####.#.....##..#..#.
# End of cycle	225: finish executing addx 5 (Register X is now 27)
#
# Sprite position: ..........................###...........
# Start cycle	226: begin executing addx -1
# During cycle	226: CRT draws pixel in position 25
# Current CRT row: ####.####.#.....##..#..#..
# End of cycle	226: finish executing addx -1 (Register X is now 27)
#
# Sprite position: ..........................###...........
# Start cycle	227: begin executing addx -1
# During cycle	227: CRT draws pixel in position 26
# Current CRT row: ####.####.#.....##..#..#..#
# End of cycle	227: finish executing addx -1 (Register X is now 26)
#
# Sprite position: .........................###............
# Start cycle	228: begin executing noop
# During cycle	228: CRT draws pixel in position 27
# Current CRT row: ####.####.#.....##..#..#..##
# End of cycle	228: finish executing noop (Register X is now 26)
#
# Sprite position: .........................###............
# Start cycle	229: begin executing addx 3
# During cycle	229: CRT draws pixel in position 28
# Current CRT row: ####.####.#.....##..#..#..##.
# End of cycle	229: finish executing addx 3 (Register X is now 26)
#
# Sprite position: .........................###............
# Start cycle	230: begin executing addx 3
# During cycle	230: CRT draws pixel in position 29
# Current CRT row: ####.####.#.....##..#..#..##..
# End of cycle	230: finish executing addx 3 (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	231: begin executing noop
# During cycle	231: CRT draws pixel in position 30
# Current CRT row: ####.####.#.....##..#..#..##..#
# End of cycle	231: finish executing noop (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	232: begin executing addx 3
# During cycle	232: CRT draws pixel in position 31
# Current CRT row: ####.####.#.....##..#..#..##..#.
# End of cycle	232: finish executing addx 3 (Register X is now 29)
#
# Sprite position: ............................###.........
# Start cycle	233: begin executing addx 3
# During cycle	233: CRT draws pixel in position 32
# Current CRT row: ####.####.#.....##..#..#..##..#..
# End of cycle	233: finish executing addx 3 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	234: begin executing addx 4
# During cycle	234: CRT draws pixel in position 33
# Current CRT row: ####.####.#.....##..#..#..##..#..#
# End of cycle	234: finish executing addx 4 (Register X is now 32)
#
# Sprite position: ...............................###......
# Start cycle	235: begin executing addx 4
# During cycle	235: CRT draws pixel in position 34
# Current CRT row: ####.####.#.....##..#..#..##..#..#.
# End of cycle	235: finish executing addx 4 (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	236: begin executing noop
# During cycle	236: CRT draws pixel in position 35
# Current CRT row: ####.####.#.....##..#..#..##..#..#.#
# End of cycle	236: finish executing noop (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	237: begin executing noop
# During cycle	237: CRT draws pixel in position 36
# Current CRT row: ####.####.#.....##..#..#..##..#..#.##
# End of cycle	237: finish executing noop (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	238: begin executing noop
# During cycle	238: CRT draws pixel in position 37
# Current CRT row: ####.####.#.....##..#..#..##..#..#.###
# End of cycle	238: finish executing noop (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	239: begin executing noop
# During cycle	239: CRT draws pixel in position 38
# Current CRT row: ####.####.#.....##..#..#..##..#..#.###.
# End of cycle	239: finish executing noop (Register X is now 36)
#
# Sprite position: ...................................###..
# Start cycle	240: begin executing noop
# During cycle	240: CRT draws pixel in position 39
# Current CRT row: ####.####.#.....##..#..#..##..#..#.###..
# End of cycle	240: finish executing noop (Register X is now 36)
#
# ####.####.####..##..#..#...##..##..###..
# #.......#.#....#..#.#..#....#.#..#.#..#.
# ###....#..###..#....####....#.#..#.###..
# #.....#...#....#....#..#....#.####.#..#.
# #....#....#....#..#.#..#.#..#.#..#.#..#.
# ####.####.#.....##..#..#..##..#..#.###..
