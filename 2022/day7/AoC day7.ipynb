# %% [markdown]
# ## Parte 1
#
# dado un listado de comandos calcular el tamaño de cada directorio y devolver la suma del tamaño de los directorios de hasta 100.000

# %%
from anytree import AnyNode, RenderTree, Resolver, PostOrderIter, PreOrderIter

# %%
def get_input(filename):
    shell_lines = []
    with open(filename) as file:
        for line in file:
            shell_lines.append(line.strip())
    return shell_lines

# %%
def build_tree(shell_lines):
    root = AnyNode(id='/', ntype='dir', dsize=0)
    resolver = Resolver('id')
    curr_node = root
    for line in shell_lines:
        if line.startswith('$ cd'):
            dir_name = line.replace('$ cd ', '')
            if dir_name == '/':
                curr_node = root
            elif dir_name == '..':
                curr_node = curr_node.parent
            else:
                curr_node = resolver.get(curr_node, dir_name)            
        elif line.startswith('$ ls'):
            None
        elif line.startswith('dir'):            
            dir_name = line.replace('dir ', '')
            new_node = AnyNode(parent = curr_node, id=dir_name, ntype='dir', dsize=0)            
        else:            
            ssize, file_name = line.split(' ')
            size = int(ssize)
            new_node = AnyNode(parent = curr_node, id=file_name, ntype='file', dsize=size)
            
    return root

# %%
def calculate_dir_size(tree):
    acum = 0
    for node in PostOrderIter(tree):
        if node.parent:
            node.parent.dsize += node.dsize
    return tree

# %%
def sum_lt_100k(tree):
    acum = 0
    for node in PreOrderIter(tree):
        if node.ntype == 'dir' and node.dsize <= 100000:
            acum += node.dsize
    return acum

# %%
shell_lines = get_input('test.txt')
tree = build_tree(shell_lines)
tree = calculate_dir_size(tree)
result = sum_lt_100k(tree)
result
# Out:
# 95437

# %%
print(RenderTree(tree))
# Out:
# AnyNode(dsize=48381165, id='/', ntype='dir')
# ├── AnyNode(dsize=94853, id='a', ntype='dir')
# │   ├── AnyNode(dsize=584, id='e', ntype='dir')
# │   │   └── AnyNode(dsize=584, id='i', ntype='file')
# │   ├── AnyNode(dsize=29116, id='f', ntype='file')
# │   ├── AnyNode(dsize=2557, id='g', ntype='file')
# │   └── AnyNode(dsize=62596, id='h.lst', ntype='file')
# ├── AnyNode(dsize=14848514, id='b.txt', ntype='file')
# ├── AnyNode(dsize=8504156, id='c.dat', ntype='file')
# └── AnyNode(dsize=24933642, id='d', ntype='dir')
#     ├── AnyNode(dsize=4060174, id='j', ntype='file')
#     ├── AnyNode(dsize=8033020, id='d.log', ntype='file')
#     ├── AnyNode(dsize=5626152, id='d.ext', ntype='file')
#     └── AnyNode(dsize=7214296, id='k', ntype='file')

# %%
shell_lines = get_input('input.txt')
tree = build_tree(shell_lines)
tree = calculate_dir_size(tree)
result = sum_lt_100k(tree)
result
# Out:
# 1182909

# %%
print(RenderTree(tree))
# Out:
# AnyNode(dsize=42677139, id='/', ntype='dir')
# ├── AnyNode(dsize=1400951, id='fcqv', ntype='dir')
# │   ├── AnyNode(dsize=101940, id='fhg', ntype='dir')
# │   │   └── AnyNode(dsize=101940, id='jljrdvw', ntype='dir')
# │   │       └── AnyNode(dsize=101940, id='vsvgjg.tpn', ntype='file')
# │   ├── AnyNode(dsize=277152, id='qldfrhm.qnr', ntype='file')
# │   ├── AnyNode(dsize=269351, id='qsd', ntype='file')
# │   └── AnyNode(dsize=752508, id='thbb', ntype='dir')
# │       ├── AnyNode(dsize=144311, id='cchngzcc.lcd', ntype='file')
# │       ├── AnyNode(dsize=178246, id='fbsj.wtl', ntype='file')
# │       ├── AnyNode(dsize=48521, id='gfsqtssb.vtg', ntype='file')
# │       ├── AnyNode(dsize=284713, id='jwl.hll', ntype='file')
# │       └── AnyNode(dsize=96717, id='wdqqqv.pcr', ntype='file')
# ├── AnyNode(dsize=1978542, id='fcv', ntype='dir')
# │   ├── AnyNode(dsize=30443, id='ffhwwg', ntype='dir')
# │   │   └── AnyNode(dsize=30443, id='hlqf', ntype='dir')
# │   │       └── AnyNode(dsize=30443, id='vrdbrwp.dss', ntype='file')
# │   ├── AnyNode(dsize=275505, id='fprcz.hrd', ntype='file')
# │   ├── AnyNode(dsize=179689, id='jwn', ntype='file')
# │   ├── AnyNode(dsize=69265, id='tfnws.drt', ntype='file')
# │   ├── AnyNode(dsize=38365, id='twvt.dbs', ntype='file')
# │   ├── AnyNode(dsize=918045, id='vcqsrw', ntype='dir')
# │   │   ├── AnyNode(dsize=272548, id='bzlnsjmv', ntype='dir')
# │   │   │   └── AnyNode(dsize=272548, id='qwqlzvzv', ntype='file')
# │   │   ├── AnyNode(dsize=165670, id='rvbtnz', ntype='dir')
# │   │   │   └── AnyNode(dsize=165670, id='jwl.lhn', ntype='file')
# │   │   ├── AnyNode(dsize=224487, id='slr', ntype='file')
# │   │   └── AnyNode(dsize=255340, id='vrdbrwp.dss', ntype='file')
# │   ├── AnyNode(dsize=247592, id='zldbq', ntype='file')
# │   └── AnyNode(dsize=219638, id='znzpm', ntype='dir')
# │       └── AnyNode(dsize=219638, id='mjwnsw', ntype='dir')
# │           └── AnyNode(dsize=219638, id='bzcb', ntype='file')
# ├── AnyNode(dsize=72939, id='hdpgfcwd', ntype='file')
# ├── AnyNode(dsize=236918, id='jlncjqh.csz', ntype='file')
# ├── AnyNode(dsize=10161796, id='jvwfwrg', ntype='dir')
# │   ├── AnyNode(dsize=356258, id='ffhwwg', ntype='dir')
# │   │   ├── AnyNode(dsize=179995, id='hcbf.dhw', ntype='file')
# │   │   └── AnyNode(dsize=176263, id='lgssjp.mnl', ntype='file')
# │   ├── AnyNode(dsize=42104, id='hmphb.qvq', ntype='file')
# │   ├── AnyNode(dsize=1992008, id='hzjpg', ntype='dir')
# │   │   ├── AnyNode(dsize=241535, id='ddlcslcs.zjh', ntype='file')
# │   │   ├── AnyNode(dsize=11756, id='ddrwfq', ntype='dir')
# │   │   │   └── AnyNode(dsize=11756, id='ffhwwg', ntype='file')
# │   │   ├── AnyNode(dsize=149750, id='mqwww', ntype='dir')
# │   │   │   └── AnyNode(dsize=149750, id='wlfmbv.cgp', ntype='file')
# │   │   ├── AnyNode(dsize=29329, id='qwqlzvzv', ntype='file')
# │   │   ├── AnyNode(dsize=91380, id='vrdbrwp.dss', ntype='file')
# │   │   ├── AnyNode(dsize=277720, id='wctwz', ntype='dir')
# │   │   │   └── AnyNode(dsize=277720, id='qldfrhm.bph', ntype='file')
# │   │   ├── AnyNode(dsize=210633, id='wdqqqv.pcr', ntype='file')
# │   │   ├── AnyNode(dsize=807854, id='wlrmbtdg', ntype='dir')
# │   │   │   ├── AnyNode(dsize=14154, id='ffhwwg', ntype='file')
# │   │   │   ├── AnyNode(dsize=229687, id='hgdjv', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=229687, id='hlw', ntype='dir')
# │   │   │   │       └── AnyNode(dsize=229687, id='cdzwfzww.wcv', ntype='file')
# │   │   │   ├── AnyNode(dsize=254189, id='qldfrhm', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=254189, id='nfbp.gcg', ntype='file')
# │   │   │   ├── AnyNode(dsize=48920, id='qwqlzvzv', ntype='file')
# │   │   │   ├── AnyNode(dsize=101228, id='wdqqqv.pcr', ntype='file')
# │   │   │   └── AnyNode(dsize=159676, id='zldbq', ntype='file')
# │   │   └── AnyNode(dsize=172051, id='zldbq', ntype='file')
# │   ├── AnyNode(dsize=4378649, id='jwl', ntype='dir')
# │   │   ├── AnyNode(dsize=277778, id='drtw', ntype='file')
# │   │   ├── AnyNode(dsize=181540, id='ghgf', ntype='dir')
# │   │   │   └── AnyNode(dsize=181540, id='zsgjptrm.thf', ntype='file')
# │   │   ├── AnyNode(dsize=1053089, id='gqlmq', ntype='dir')
# │   │   │   ├── AnyNode(dsize=264524, id='ffhwwg', ntype='dir')
# │   │   │   │   ├── AnyNode(dsize=242533, id='qwqlzvzv', ntype='file')
# │   │   │   │   └── AnyNode(dsize=21991, id='wdqqqv.pcr', ntype='file')
# │   │   │   ├── AnyNode(dsize=283989, id='hzpwn', ntype='file')
# │   │   │   ├── AnyNode(dsize=282619, id='jwl', ntype='dir')
# │   │   │   │   ├── AnyNode(dsize=179926, id='jfgbmb.qsd', ntype='file')
# │   │   │   │   └── AnyNode(dsize=102693, id='zjv', ntype='dir')
# │   │   │   │       └── AnyNode(dsize=102693, id='ffhwwg.hrt', ntype='file')
# │   │   │   ├── AnyNode(dsize=159376, id='pqdqntr', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=159376, id='nqwcsdmv', ntype='file')
# │   │   │   └── AnyNode(dsize=62581, id='vrdbrwp.dss', ntype='file')
# │   │   ├── AnyNode(dsize=163875, id='jwl.pmm', ntype='file')
# │   │   ├── AnyNode(dsize=590544, id='mjm', ntype='dir')
# │   │   │   ├── AnyNode(dsize=273410, id='hdbmpnfv', ntype='file')
# │   │   │   ├── AnyNode(dsize=8169, id='qwqlzvzv', ntype='file')
# │   │   │   ├── AnyNode(dsize=87728, id='tfgq.vbt', ntype='file')
# │   │   │   └── AnyNode(dsize=221237, id='vrdbrwp.dss', ntype='file')
# │   │   └── AnyNode(dsize=2111823, id='qgq', ntype='dir')
# │   │       ├── AnyNode(dsize=904158, id='dgq', ntype='dir')
# │   │       │   ├── AnyNode(dsize=541118, id='ffhwwg', ntype='dir')
# │   │       │   │   ├── AnyNode(dsize=117790, id='sqhrdmd.thc', ntype='file')
# │   │       │   │   ├── AnyNode(dsize=186465, id='tfctr.scc', ntype='file')
# │   │       │   │   └── AnyNode(dsize=236863, id='wdqqqv.pcr', ntype='file')
# │   │       │   ├── AnyNode(dsize=237291, id='nfqzn', ntype='file')
# │   │       │   ├── AnyNode(dsize=70142, id='qfnrvmp.vbb', ntype='file')
# │   │       │   └── AnyNode(dsize=55607, id='zldbq', ntype='file')
# │   │       ├── AnyNode(dsize=244567, id='hlw', ntype='dir')
# │   │       │   └── AnyNode(dsize=244567, id='wrnplfgg.pcw', ntype='file')
# │   │       ├── AnyNode(dsize=164971, id='jvwfwrg', ntype='file')
# │   │       ├── AnyNode(dsize=105997, id='jwl', ntype='dir')
# │   │       │   └── AnyNode(dsize=105997, id='lpsg.jjl', ntype='file')
# │   │       ├── AnyNode(dsize=158534, id='qftjvcz.pfv', ntype='file')
# │   │       ├── AnyNode(dsize=251561, id='qzzpmh', ntype='file')
# │   │       └── AnyNode(dsize=282035, id='wsz', ntype='file')
# │   ├── AnyNode(dsize=180419, id='nmz', ntype='dir')
# │   │   ├── AnyNode(dsize=51802, id='qwqlzvzv', ntype='file')
# │   │   └── AnyNode(dsize=128617, id='zldbq', ntype='file')
# │   ├── AnyNode(dsize=243217, id='qldfrhm.rws', ntype='file')
# │   ├── AnyNode(dsize=945438, id='tdjtv', ntype='dir')
# │   │   ├── AnyNode(dsize=35406, id='jvwfwrg', ntype='dir')
# │   │   │   └── AnyNode(dsize=35406, id='wdqqqv.pcr', ntype='file')
# │   │   ├── AnyNode(dsize=338803, id='mdmwf', ntype='dir')
# │   │   │   ├── AnyNode(dsize=117473, id='ffhwwg', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=117473, id='hdcv.cwj', ntype='file')
# │   │   │   ├── AnyNode(dsize=15609, id='rdpwqw.pfv', ntype='file')
# │   │   │   └── AnyNode(dsize=205721, id='zldbq', ntype='file')
# │   │   └── AnyNode(dsize=571229, id='rlpbrq', ntype='dir')
# │   │       ├── AnyNode(dsize=120058, id='dgddvmt.fnv', ntype='file')
# │   │       ├── AnyNode(dsize=194704, id='ffhwwg', ntype='file')
# │   │       └── AnyNode(dsize=256467, id='qwqlzvzv', ntype='file')
# │   └── AnyNode(dsize=2023703, id='wdn', ntype='dir')
# │       ├── AnyNode(dsize=170094, id='bzqsnv', ntype='file')
# │       ├── AnyNode(dsize=281457, id='gqmghw', ntype='dir')
# │       │   └── AnyNode(dsize=281457, id='tlgbcrh', ntype='dir')
# │       │       └── AnyNode(dsize=281457, id='ztjhcrwf.ljf', ntype='file')
# │       ├── AnyNode(dsize=150252, id='gwgz.fnf', ntype='file')
# │       ├── AnyNode(dsize=243953, id='jfgbmb.qsd', ntype='file')
# │       ├── AnyNode(dsize=123382, id='qwqlzvzv', ntype='file')
# │       ├── AnyNode(dsize=96220, id='wpc.swm', ntype='file')
# │       └── AnyNode(dsize=958345, id='ztqbhjr', ntype='dir')
# │           ├── AnyNode(dsize=271212, id='jfgbmb.qsd', ntype='file')
# │           ├── AnyNode(dsize=329280, id='nbhq', ntype='dir')
# │           │   ├── AnyNode(dsize=179096, id='hlw.hrh', ntype='file')
# │           │   └── AnyNode(dsize=150184, id='wdqqqv.pcr', ntype='file')
# │           ├── AnyNode(dsize=97774, id='vfmmj', ntype='dir')
# │           │   ├── AnyNode(dsize=57445, id='hlw.pfb', ntype='file')
# │           │   └── AnyNode(dsize=40329, id='qldfrhm', ntype='file')
# │           └── AnyNode(dsize=260079, id='vrdbrwp.dss', ntype='file')
# ├── AnyNode(dsize=5370216, id='tzwpllhq', ntype='dir')
# │   ├── AnyNode(dsize=33596, id='cmwwd', ntype='file')
# │   ├── AnyNode(dsize=16963, id='hlw.jrw', ntype='file')
# │   ├── AnyNode(dsize=161107, id='hlw.npq', ntype='file')
# │   ├── AnyNode(dsize=1439695, id='jwv', ntype='dir')
# │   │   ├── AnyNode(dsize=287407, id='bgswd', ntype='dir')
# │   │   │   ├── AnyNode(dsize=70441, id='hdgt', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=70441, id='fnv.bpl', ntype='file')
# │   │   │   └── AnyNode(dsize=216966, id='ldbg.dzh', ntype='file')
# │   │   ├── AnyNode(dsize=188795, id='hlw', ntype='file')
# │   │   ├── AnyNode(dsize=326711, id='jvwfwrg', ntype='dir')
# │   │   │   ├── AnyNode(dsize=257337, id='mctsws', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=257337, id='qsgvbj', ntype='file')
# │   │   │   └── AnyNode(dsize=69374, id='qldfrhm', ntype='file')
# │   │   ├── AnyNode(dsize=161061, id='jwl', ntype='dir')
# │   │   │   └── AnyNode(dsize=161061, id='ffhwwg', ntype='file')
# │   │   ├── AnyNode(dsize=63455, id='mbcb', ntype='dir')
# │   │   │   ├── AnyNode(dsize=55629, id='fbhhq', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=55629, id='vnn', ntype='dir')
# │   │   │   │       └── AnyNode(dsize=55629, id='cthtjm.wbt', ntype='file')
# │   │   │   └── AnyNode(dsize=7826, id='rgjwh', ntype='dir')
# │   │   │       └── AnyNode(dsize=7826, id='wrhpmqd.fvw', ntype='file')
# │   │   ├── AnyNode(dsize=188516, id='qldfrhm', ntype='dir')
# │   │   │   ├── AnyNode(dsize=14471, id='hlw.lwh', ntype='file')
# │   │   │   ├── AnyNode(dsize=163165, id='jnpgzcmt', ntype='file')
# │   │   │   └── AnyNode(dsize=10880, id='qwqlzvzv', ntype='file')
# │   │   ├── AnyNode(dsize=30173, id='qwqlzvzv', ntype='file')
# │   │   └── AnyNode(dsize=193577, id='zldbq', ntype='file')
# │   ├── AnyNode(dsize=152431, id='nqf.jjg', ntype='file')
# │   ├── AnyNode(dsize=3106371, id='qldfrhm', ntype='dir')
# │   │   ├── AnyNode(dsize=218749, id='ffhwwg', ntype='dir')
# │   │   │   └── AnyNode(dsize=218749, id='ffhwwg.ztr', ntype='file')
# │   │   ├── AnyNode(dsize=1972044, id='jwl', ntype='dir')
# │   │   │   ├── AnyNode(dsize=40245, id='cbhtl.frv', ntype='file')
# │   │   │   ├── AnyNode(dsize=268818, id='fmwvvg', ntype='file')
# │   │   │   ├── AnyNode(dsize=161866, id='nqp', ntype='file')
# │   │   │   ├── AnyNode(dsize=43660, id='nsvjcpc', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=43660, id='wtnhh.zgw', ntype='file')
# │   │   │   ├── AnyNode(dsize=864119, id='nwdvblg', ntype='dir')
# │   │   │   │   ├── AnyNode(dsize=446213, id='cltj', ntype='dir')
# │   │   │   │   │   ├── AnyNode(dsize=86970, id='dlzsw.whj', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=111805, id='qwqlzvzv', ntype='file')
# │   │   │   │   │   └── AnyNode(dsize=247438, id='zldbq', ntype='file')
# │   │   │   │   └── AnyNode(dsize=417906, id='fds', ntype='dir')
# │   │   │   │       ├── AnyNode(dsize=49560, id='fsrvhv.lhd', ntype='file')
# │   │   │   │       ├── AnyNode(dsize=234970, id='jvwfwrg.pfd', ntype='file')
# │   │   │   │       └── AnyNode(dsize=133376, id='qgbmc', ntype='file')
# │   │   │   ├── AnyNode(dsize=171528, id='qldfrhm', ntype='file')
# │   │   │   ├── AnyNode(dsize=139542, id='qqmb', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=139542, id='qzm.jjz', ntype='file')
# │   │   │   └── AnyNode(dsize=282266, id='wdqqqv.pcr', ntype='file')
# │   │   ├── AnyNode(dsize=15164, id='ldmm', ntype='file')
# │   │   ├── AnyNode(dsize=188544, id='pwg.zsf', ntype='file')
# │   │   ├── AnyNode(dsize=255566, id='qjlggt', ntype='file')
# │   │   ├── AnyNode(dsize=396406, id='tbngqwb', ntype='dir')
# │   │   │   ├── AnyNode(dsize=45969, id='jwl', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=45969, id='ltvvm', ntype='file')
# │   │   │   ├── AnyNode(dsize=273706, id='vcfmt.jqv', ntype='file')
# │   │   │   └── AnyNode(dsize=76731, id='wdqqqv.pcr', ntype='file')
# │   │   └── AnyNode(dsize=59898, id='zldbq', ntype='file')
# │   ├── AnyNode(dsize=444930, id='swmwvl', ntype='dir')
# │   │   ├── AnyNode(dsize=32187, id='dzn.rnz', ntype='file')
# │   │   ├── AnyNode(dsize=235867, id='gsj', ntype='dir')
# │   │   │   ├── AnyNode(dsize=83665, id='fpzj', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=83665, id='btwqdhnf.qwz', ntype='file')
# │   │   │   └── AnyNode(dsize=152202, id='wntpsp.tbf', ntype='file')
# │   │   ├── AnyNode(dsize=83763, id='jfgbmb.qsd', ntype='file')
# │   │   └── AnyNode(dsize=93113, id='vrdbrwp.dss', ntype='file')
# │   └── AnyNode(dsize=15123, id='wzpth', ntype='dir')
# │       └── AnyNode(dsize=15123, id='snhss', ntype='dir')
# │           └── AnyNode(dsize=15123, id='hlw', ntype='dir')
# │               └── AnyNode(dsize=15123, id='qwqlzvzv', ntype='file')
# ├── AnyNode(dsize=23427191, id='vglf', ntype='dir')
# │   ├── AnyNode(dsize=214742, id='gdjmt', ntype='dir')
# │   │   └── AnyNode(dsize=214742, id='jfgbmb.qsd', ntype='file')
# │   ├── AnyNode(dsize=12229486, id='hnnw', ntype='dir')
# │   │   ├── AnyNode(dsize=390981, id='ffhwwg', ntype='dir')
# │   │   │   ├── AnyNode(dsize=129823, id='dsqwrdnq', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=129823, id='pngjr.rpg', ntype='file')
# │   │   │   └── AnyNode(dsize=261158, id='jvwfwrg.plf', ntype='file')
# │   │   ├── AnyNode(dsize=217384, id='jfgbmb.qsd', ntype='file')
# │   │   ├── AnyNode(dsize=153385, id='jvwfwrg', ntype='file')
# │   │   ├── AnyNode(dsize=9203495, id='jwl', ntype='dir')
# │   │   │   ├── AnyNode(dsize=199534, id='bzq', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=199534, id='jvwfwrg.tnt', ntype='file')
# │   │   │   ├── AnyNode(dsize=215828, id='hpqtdllh', ntype='file')
# │   │   │   ├── AnyNode(dsize=7086475, id='jjmndb', ntype='dir')
# │   │   │   │   ├── AnyNode(dsize=484200, id='cbfdqtc', ntype='dir')
# │   │   │   │   │   ├── AnyNode(dsize=39125, id='ffhwwg.fpg', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=264178, id='jpnslr.qqt', ntype='file')
# │   │   │   │   │   └── AnyNode(dsize=180897, id='wjmfvtvn', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=217994, id='gnjlnz', ntype='dir')
# │   │   │   │   │   └── AnyNode(dsize=217994, id='jwl.ddh', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=1707306, id='hlw', ntype='dir')
# │   │   │   │   │   ├── AnyNode(dsize=284909, id='chgwjl', ntype='dir')
# │   │   │   │   │   │   └── AnyNode(dsize=284909, id='jwl.qqp', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=47411, id='dsz', ntype='dir')
# │   │   │   │   │   │   └── AnyNode(dsize=47411, id='bsshfjl.wbd', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=165192, id='ffhwwg.qfc', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=40771, id='gzph.mvb', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=46495, id='jvwfwrg', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=122203, id='lhgfb.blq', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=175167, id='qwqlzvzv', ntype='file')
# │   │   │   │   │   └── AnyNode(dsize=825158, id='ttr', ntype='dir')
# │   │   │   │   │       ├── AnyNode(dsize=203288, id='fgbgl', ntype='dir')
# │   │   │   │   │       │   └── AnyNode(dsize=203288, id='scclvct', ntype='file')
# │   │   │   │   │       ├── AnyNode(dsize=365950, id='qsflswrq', ntype='dir')
# │   │   │   │   │       │   ├── AnyNode(dsize=222611, id='ffhwwg', ntype='file')
# │   │   │   │   │       │   └── AnyNode(dsize=143339, id='thrwtw.nsg', ntype='file')
# │   │   │   │   │       ├── AnyNode(dsize=5609, id='sfz', ntype='file')
# │   │   │   │   │       └── AnyNode(dsize=250311, id='vrdbrwp.dss', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=201443, id='lgdvsvc.wvp', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=600157, id='lzlwstch', ntype='dir')
# │   │   │   │   │   ├── AnyNode(dsize=51165, id='ffhwwg', ntype='dir')
# │   │   │   │   │   │   └── AnyNode(dsize=51165, id='hlw.hdn', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=54571, id='hwmzp', ntype='dir')
# │   │   │   │   │   │   └── AnyNode(dsize=54571, id='qwqlzvzv', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=130055, id='jvwfwrg', ntype='dir')
# │   │   │   │   │   │   └── AnyNode(dsize=130055, id='qldfrhm', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=160215, id='ndpbn', ntype='dir')
# │   │   │   │   │   │   └── AnyNode(dsize=160215, id='hptz.zms', ntype='file')
# │   │   │   │   │   └── AnyNode(dsize=204151, id='qllzhd', ntype='dir')
# │   │   │   │   │       ├── AnyNode(dsize=41306, id='hwnllpw.vjp', ntype='file')
# │   │   │   │   │       └── AnyNode(dsize=162845, id='vrdbrwp.dss', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=175514, id='nlvh.rjc', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=2424427, id='qldfrhm', ntype='dir')
# │   │   │   │   │   ├── AnyNode(dsize=181254, id='bwcg', ntype='dir')
# │   │   │   │   │   │   └── AnyNode(dsize=181254, id='wpzpd', ntype='file')
# │   │   │   │   │   └── AnyNode(dsize=2243173, id='ffhwwg', ntype='dir')
# │   │   │   │   │       ├── AnyNode(dsize=240618, id='cdmlz.wsf', ntype='file')
# │   │   │   │   │       ├── AnyNode(dsize=178372, id='ffhwwg', ntype='dir')
# │   │   │   │   │       │   ├── AnyNode(dsize=13278, id='wcc.qmr', ntype='file')
# │   │   │   │   │       │   └── AnyNode(dsize=165094, id='wdqqqv.pcr', ntype='file')
# │   │   │   │   │       ├── AnyNode(dsize=201345, id='jfww', ntype='file')
# │   │   │   │   │       ├── AnyNode(dsize=128709, id='jwl.gwc', ntype='file')
# │   │   │   │   │       ├── AnyNode(dsize=284209, id='pswsrf.wwt', ntype='file')
# │   │   │   │   │       └── AnyNode(dsize=1209920, id='qldfrhm', ntype='dir')
# │   │   │   │   │           ├── AnyNode(dsize=104797, id='ccgfmcnc.jrg', ntype='file')
# │   │   │   │   │           ├── AnyNode(dsize=273814, id='hlw.pnt', ntype='file')
# │   │   │   │   │           ├── AnyNode(dsize=182685, id='jvwfwrg.szl', ntype='file')
# │   │   │   │   │           ├── AnyNode(dsize=190595, id='stjhgqd', ntype='file')
# │   │   │   │   │           ├── AnyNode(dsize=221672, id='stpvb', ntype='dir')
# │   │   │   │   │           │   └── AnyNode(dsize=221672, id='vrdbrwp.dss', ntype='file')
# │   │   │   │   │           ├── AnyNode(dsize=105499, id='vbqw.vwc', ntype='file')
# │   │   │   │   │           └── AnyNode(dsize=130858, id='zldj', ntype='dir')
# │   │   │   │   │               └── AnyNode(dsize=130858, id='jwl', ntype='dir')
# │   │   │   │   │                   └── AnyNode(dsize=130858, id='jhqhfrbp.nff', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=144450, id='qwqlzvzv', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=348914, id='ssh', ntype='dir')
# │   │   │   │   │   ├── AnyNode(dsize=65814, id='jfgbmb.qsd', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=212356, id='jvwfwrg', ntype='dir')
# │   │   │   │   │   │   └── AnyNode(dsize=212356, id='jfgf.szv', ntype='file')
# │   │   │   │   │   └── AnyNode(dsize=70744, id='zqhftjbs.jwd', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=391437, id='tbdhtqn', ntype='dir')
# │   │   │   │   │   ├── AnyNode(dsize=37228, id='ffhwwg.vvc', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=69069, id='nrtgtbmp.qlv', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=118846, id='rmrwm', ntype='dir')
# │   │   │   │   │   │   └── AnyNode(dsize=118846, id='qldfrhm.hns', ntype='file')
# │   │   │   │   │   └── AnyNode(dsize=166294, id='zldbq', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=150014, id='ttp.zqf', ntype='file')
# │   │   │   │   └── AnyNode(dsize=240619, id='wdqqqv.pcr', ntype='file')
# │   │   │   ├── AnyNode(dsize=348414, id='pjzqjbd', ntype='dir')
# │   │   │   │   ├── AnyNode(dsize=259092, id='cqlfdc.qdp', ntype='file')
# │   │   │   │   └── AnyNode(dsize=89322, id='nmpvmdlp', ntype='file')
# │   │   │   ├── AnyNode(dsize=82637, id='pmslv', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=82637, id='jwl.lhz', ntype='file')
# │   │   │   ├── AnyNode(dsize=913784, id='smfg', ntype='dir')
# │   │   │   │   ├── AnyNode(dsize=23958, id='gfbpcr', ntype='dir')
# │   │   │   │   │   └── AnyNode(dsize=23958, id='hnpgr.htf', ntype='file')
# │   │   │   │   └── AnyNode(dsize=889826, id='sghtlzqv', ntype='dir')
# │   │   │   │       ├── AnyNode(dsize=275943, id='jfgbmb.qsd', ntype='file')
# │   │   │   │       ├── AnyNode(dsize=149592, id='qwqlzvzv', ntype='file')
# │   │   │   │       ├── AnyNode(dsize=285215, id='sgptfc.msd', ntype='file')
# │   │   │   │       └── AnyNode(dsize=179076, id='zldbq', ntype='file')
# │   │   │   └── AnyNode(dsize=356823, id='wmjjwh', ntype='dir')
# │   │   │       ├── AnyNode(dsize=198333, id='jfgbmb.qsd', ntype='file')
# │   │   │       ├── AnyNode(dsize=59553, id='qwqlzvzv', ntype='file')
# │   │   │       ├── AnyNode(dsize=91883, id='wdqqqv.pcr', ntype='file')
# │   │   │       └── AnyNode(dsize=7054, id='zldbq', ntype='file')
# │   │   ├── AnyNode(dsize=1928944, id='shdt', ntype='dir')
# │   │   │   ├── AnyNode(dsize=27781, id='hlw.vcl', ntype='file')
# │   │   │   ├── AnyNode(dsize=255994, id='jpd', ntype='file')
# │   │   │   ├── AnyNode(dsize=845246, id='mrgppm', ntype='dir')
# │   │   │   │   ├── AnyNode(dsize=494240, id='ghzhzzp', ntype='dir')
# │   │   │   │   │   ├── AnyNode(dsize=234131, id='bqplqq', ntype='dir')
# │   │   │   │   │   │   └── AnyNode(dsize=234131, id='lntldzhp', ntype='file')
# │   │   │   │   │   └── AnyNode(dsize=260109, id='vtqgwsj', ntype='dir')
# │   │   │   │   │       └── AnyNode(dsize=260109, id='qrzrfzr', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=112258, id='jwl', ntype='dir')
# │   │   │   │   │   └── AnyNode(dsize=112258, id='ffhwwg.wvp', ntype='file')
# │   │   │   │   └── AnyNode(dsize=238748, id='tgpm', ntype='dir')
# │   │   │   │       ├── AnyNode(dsize=70960, id='hlw', ntype='dir')
# │   │   │   │       │   └── AnyNode(dsize=70960, id='qwqlzvzv', ntype='file')
# │   │   │   │       └── AnyNode(dsize=167788, id='zldbq', ntype='file')
# │   │   │   ├── AnyNode(dsize=142087, id='mwvgmjmb', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=142087, id='pvpw.wtv', ntype='file')
# │   │   │   ├── AnyNode(dsize=125853, id='nsbrbcq', ntype='dir')
# │   │   │   │   └── AnyNode(dsize=125853, id='hljjp', ntype='dir')
# │   │   │   │       └── AnyNode(dsize=125853, id='jfgbmb.qsd', ntype='file')
# │   │   │   ├── AnyNode(dsize=263384, id='rbwbqf.qjc', ntype='file')
# │   │   │   ├── AnyNode(dsize=251640, id='tgr.rdc', ntype='file')
# │   │   │   └── AnyNode(dsize=16959, id='zldbq', ntype='file')
# │   │   ├── AnyNode(dsize=143935, id='vrdbrwp.dss', ntype='file')
# │   │   ├── AnyNode(dsize=90319, id='zldbq', ntype='file')
# │   │   └── AnyNode(dsize=101043, id='zqvwfhrz.rfz', ntype='file')
# │   ├── AnyNode(dsize=9319261, id='htqzfcc', ntype='dir')
# │   │   ├── AnyNode(dsize=268481, id='cqs', ntype='dir')
# │   │   │   ├── AnyNode(dsize=232548, id='nnv.wph', ntype='file')
# │   │   │   └── AnyNode(dsize=35933, id='rwqj.crp', ntype='file')
# │   │   ├── AnyNode(dsize=115805, id='dsnpcnv', ntype='dir')
# │   │   │   └── AnyNode(dsize=115805, id='ffhwwg.tvt', ntype='file')
# │   │   ├── AnyNode(dsize=1778764, id='ffhwwg', ntype='dir')
# │   │   │   ├── AnyNode(dsize=1525901, id='qldfrhm', ntype='dir')
# │   │   │   │   ├── AnyNode(dsize=221567, id='qwqlzvzv', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=879834, id='rsztzjcm', ntype='dir')
# │   │   │   │   │   ├── AnyNode(dsize=268313, id='frdpwjsh.wsh', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=283644, id='jfgbmb.qsd', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=212461, id='jhdcdm', ntype='dir')
# │   │   │   │   │   │   └── AnyNode(dsize=212461, id='qwqlzvzv', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=84130, id='jvwfwrg.vsd', ntype='file')
# │   │   │   │   │   └── AnyNode(dsize=31286, id='jwl.rth', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=33248, id='vrdbrwp.dss', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=114731, id='wdqqqv.pcr', ntype='file')
# │   │   │   │   └── AnyNode(dsize=276521, id='zldbq', ntype='file')
# │   │   │   └── AnyNode(dsize=252863, id='wjj', ntype='dir')
# │   │   │       ├── AnyNode(dsize=89758, id='jvwfwrg.mmg', ntype='file')
# │   │   │       └── AnyNode(dsize=163105, id='vrdbrwp.dss', ntype='file')
# │   │   ├── AnyNode(dsize=90664, id='jfgbmb.qsd', ntype='file')
# │   │   ├── AnyNode(dsize=92316, id='lsjtfbvt', ntype='file')
# │   │   ├── AnyNode(dsize=278389, id='mftm', ntype='dir')
# │   │   │   └── AnyNode(dsize=278389, id='bbth.bht', ntype='file')
# │   │   ├── AnyNode(dsize=28122, id='mmgn', ntype='dir')
# │   │   │   └── AnyNode(dsize=28122, id='zldbq', ntype='file')
# │   │   ├── AnyNode(dsize=3635989, id='qqvzvw', ntype='dir')
# │   │   │   ├── AnyNode(dsize=746938, id='mjw', ntype='dir')
# │   │   │   │   ├── AnyNode(dsize=146142, id='cvn', ntype='dir')
# │   │   │   │   │   └── AnyNode(dsize=146142, id='ggtd.jlp', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=130120, id='dlgzc', ntype='dir')
# │   │   │   │   │   └── AnyNode(dsize=130120, id='wpc', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=10631, id='jfgbmb.qsd', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=206351, id='qldfrhm.hgf', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=136824, id='qwqlzvzv', ntype='file')
# │   │   │   │   └── AnyNode(dsize=116870, id='qwzczrcf', ntype='file')
# │   │   │   ├── AnyNode(dsize=2463904, id='qldfrhm', ntype='dir')
# │   │   │   │   ├── AnyNode(dsize=260238, id='bpf.jbv', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=270180, id='cwdnf', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=1022318, id='czwwzj', ntype='dir')
# │   │   │   │   │   ├── AnyNode(dsize=176717, id='cpwwqrph', ntype='dir')
# │   │   │   │   │   │   └── AnyNode(dsize=176717, id='jvwfwrg', ntype='dir')
# │   │   │   │   │   │       └── AnyNode(dsize=176717, id='jfgbmb.qsd', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=19863, id='jfgbmb.qsd', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=741823, id='snl', ntype='dir')
# │   │   │   │   │   │   ├── AnyNode(dsize=322764, id='btngcvt', ntype='dir')
# │   │   │   │   │   │   │   ├── AnyNode(dsize=172859, id='jwl.smp', ntype='file')
# │   │   │   │   │   │   │   └── AnyNode(dsize=149905, id='tgcqmbrn', ntype='dir')
# │   │   │   │   │   │   │       └── AnyNode(dsize=149905, id='jvwfwrg', ntype='file')
# │   │   │   │   │   │   ├── AnyNode(dsize=145399, id='ffhwwg', ntype='dir')
# │   │   │   │   │   │   │   └── AnyNode(dsize=145399, id='qldfrhm.hbg', ntype='file')
# │   │   │   │   │   │   ├── AnyNode(dsize=53428, id='gchwbc.jtf', ntype='file')
# │   │   │   │   │   │   └── AnyNode(dsize=220232, id='vrdbrwp.dss', ntype='file')
# │   │   │   │   │   └── AnyNode(dsize=83915, id='vrdbrwp.dss', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=50884, id='jvwfwrg.fmq', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=204422, id='mjpzgbww', ntype='dir')
# │   │   │   │   │   ├── AnyNode(dsize=52355, id='bwzwfjtc.rmn', ntype='file')
# │   │   │   │   │   ├── AnyNode(dsize=5856, id='ffhwwg.tnh', ntype='file')
# │   │   │   │   │   └── AnyNode(dsize=146211, id='scbdnlgl', ntype='file')
# │   │   │   │   ├── AnyNode(dsize=252028, id='qtdzw.bmb', ntype='file')
# │   │   │   │   └── AnyNode(dsize=403834, id='rzqj', ntype='dir')
# │   │   │   │       ├── AnyNode(dsize=81971, id='jmjszd', ntype='dir')
# │   │   │   │       │   └── AnyNode(dsize=81971, id='qldfrhm', ntype='file')
# │   │   │   │       ├── AnyNode(dsize=134481, id='vgr', ntype='file')
# │   │   │   │       └── AnyNode(dsize=187382, id='vrdbrwp.dss', ntype='file')
# │   │   │   └── AnyNode(dsize=425147, id='zbmpdwtc', ntype='dir')
# │   │   │       ├── AnyNode(dsize=193744, id='jvntrn', ntype='file')
# │   │   │       └── AnyNode(dsize=231403, id='qwqlzvzv', ntype='file')
# │   │   ├── AnyNode(dsize=166400, id='qwqlzvzv', ntype='file')
# │   │   ├── AnyNode(dsize=2562, id='vtf', ntype='dir')
# │   │   │   └── AnyNode(dsize=2562, id='vzngcbq', ntype='file')
# │   │   └── AnyNode(dsize=2861769, id='wrbwbdt', ntype='dir')
# │   │       ├── AnyNode(dsize=2832508, id='brzwbmc', ntype='dir')
# │   │       │   ├── AnyNode(dsize=1057988, id='ggh', ntype='dir')
# │   │       │   │   ├── AnyNode(dsize=1039264, id='cqrmsltg', ntype='dir')
# │   │       │   │   │   ├── AnyNode(dsize=139875, id='ffhwwg', ntype='dir')
# │   │       │   │   │   │   └── AnyNode(dsize=139875, id='hlw', ntype='dir')
# │   │       │   │   │   │       └── AnyNode(dsize=139875, id='ljnfchr.frr', ntype='file')
# │   │       │   │   │   ├── AnyNode(dsize=141078, id='jvwfwrg', ntype='dir')
# │   │       │   │   │   │   └── AnyNode(dsize=141078, id='zldbq', ntype='file')
# │   │       │   │   │   ├── AnyNode(dsize=41263, id='pmrmh.zmn', ntype='file')
# │   │       │   │   │   └── AnyNode(dsize=717048, id='tcjr', ntype='dir')
# │   │       │   │   │       ├── AnyNode(dsize=243203, id='hnngpdc', ntype='dir')
# │   │       │   │   │       │   └── AnyNode(dsize=243203, id='gchtc.sst', ntype='file')
# │   │       │   │   │       ├── AnyNode(dsize=153685, id='jwl', ntype='file')
# │   │       │   │   │       ├── AnyNode(dsize=93502, id='nwlsf.dbq', ntype='file')
# │   │       │   │   │       └── AnyNode(dsize=226658, id='qwqlzvzv', ntype='file')
# │   │       │   │   └── AnyNode(dsize=18724, id='mrlwwdv.ffb', ntype='file')
# │   │       │   ├── AnyNode(dsize=174287, id='jfgbmb.qsd', ntype='file')
# │   │       │   ├── AnyNode(dsize=62087, id='jwl', ntype='dir')
# │   │       │   │   └── AnyNode(dsize=62087, id='hfp.cfv', ntype='file')
# │   │       │   ├── AnyNode(dsize=247329, id='mpdz', ntype='file')
# │   │       │   ├── AnyNode(dsize=976002, id='thm', ntype='dir')
# │   │       │   │   ├── AnyNode(dsize=228008, id='dfqgcd.frc', ntype='file')
# │   │       │   │   ├── AnyNode(dsize=167850, id='glblcw', ntype='file')
# │   │       │   │   └── AnyNode(dsize=580144, id='jvwfwrg', ntype='dir')
# │   │       │   │       ├── AnyNode(dsize=258985, id='ffhwwg', ntype='dir')
# │   │       │   │       │   └── AnyNode(dsize=258985, id='jfgbmb.qsd', ntype='file')
# │   │       │   │       ├── AnyNode(dsize=150671, id='jgvf', ntype='dir')
# │   │       │   │       │   └── AnyNode(dsize=150671, id='rdplqftl', ntype='file')
# │   │       │   │       └── AnyNode(dsize=170488, id='qmc.vgf', ntype='file')
# │   │       │   ├── AnyNode(dsize=83546, id='vrdbrwp.dss', ntype='file')
# │   │       │   └── AnyNode(dsize=231269, id='wmwhhhmn.rms', ntype='file')
# │   │       └── AnyNode(dsize=29261, id='hlw', ntype='file')
# │   ├── AnyNode(dsize=500913, id='nqf', ntype='dir')
# │   │   └── AnyNode(dsize=500913, id='rglrpqd', ntype='dir')
# │   │       ├── AnyNode(dsize=276785, id='nnbs.dhr', ntype='file')
# │   │       └── AnyNode(dsize=224128, id='qwqlzvzv', ntype='file')
# │   ├── AnyNode(dsize=269558, id='qldfrhm', ntype='file')
# │   ├── AnyNode(dsize=116732, id='rqg.zbf', ntype='file')
# │   ├── AnyNode(dsize=703677, id='tvmqzwmn', ntype='dir')
# │   │   ├── AnyNode(dsize=47655, id='jfgbmb.qsd', ntype='file')
# │   │   ├── AnyNode(dsize=233646, id='qwqlzvzv', ntype='file')
# │   │   ├── AnyNode(dsize=237245, id='rqfp', ntype='file')
# │   │   └── AnyNode(dsize=185131, id='whntfvm.sfz', ntype='file')
# │   └── AnyNode(dsize=72822, id='vrdbrwp.dss', ntype='file')
# └── AnyNode(dsize=28586, id='wzljr.zvp', ntype='file')

# %% [markdown]
# ## Parte 2:
#
# el espacio total del dispositivo es de 70000000, para la actualización se necesita al menos 30000000.
#
# elegir el directorio más pequeño que libere espacio suficiente para la actualización.

# %%
def get_min_directory(tree, total, needed):
    free_space = total - tree.dsize
    lacking = needed - free_space
        
    dir_sizes = []
    for node in PreOrderIter(tree):
        if node.ntype == 'dir':
            dir_sizes.append(node.dsize)
    
    dir_sizes.sort()
    
    for d in dir_sizes:
        if d > lacking:
            return d

# %%
shell_lines = get_input('test.txt')
tree = build_tree(shell_lines)
tree = calculate_dir_size(tree)
result = get_min_directory(tree, 70000000, 30000000)
result
# Out:
# 24933642

# %%
shell_lines = get_input('input.txt')
tree = build_tree(shell_lines)
tree = calculate_dir_size(tree)
result = get_min_directory(tree, 70000000, 30000000)
result
# Out:
# 2832508
